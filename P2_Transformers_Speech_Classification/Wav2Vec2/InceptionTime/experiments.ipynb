# %%
import matplotlib.pyplot as plt
from inception_time import *
from prepare_data import *
import pandas as pd
from Wav2Vec2.visualizations import * 
from sklearn.metrics import confusion_matrix

# %%
train_dir = './data/train2/audio/'

# %%
X_train, X_val, y_train, y_val = create_prepare_data(train_dir)
# Out:
# 0 right/988e2f9a_nohash_0.wav
# /Users/zuzannaglinka/DeepLearning/2024Z_DeepLearning/P2_Transformers_Speech_Classification/prepare_data.py:26: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(sig[:16000],
# 2000 right/7e843da8_nohash_0.wav
# 4000 eight/fa446c16_nohash_0.wav
# 6000 cat/b00c4c53_nohash_0.wav
# 8000 tree/617de221_nohash_0.wav
# 10000 happy/dd086776_nohash_0.wav
# 12000 go/5be23def_nohash_0.wav
# 14000 go/778a4a01_nohash_1.wav
# 16000 silence/frag47_exercise_bike.wav
# 18000 no/a8ee11c7_nohash_1.wav
# 20000 no/b9f46737_nohash_0.wav
# 22000 wow/cc592808_nohash_1.wav
# 24000 nine/5de8f2f0_nohash_3.wav
# 26000 left/3bc21161_nohash_4.wav
# 28000 stop/826268f8_nohash_0.wav
# 30000 three/d7ca14ef_nohash_0.wav
# 32000 sheila/e2286c18_nohash_0.wav
# 34000 one/73124b26_nohash_1.wav
# 36000 bird/5f1b1051_nohash_0.wav
# 38000 zero/36050ef3_nohash_0.wav
# 40000 seven/31d68957_nohash_2.wav
# 42000 seven/9a7c1f83_nohash_4.wav
# 44000 up/77def3ee_nohash_1.wav
# 46000 marvin/ad5aeec2_nohash_0.wav
# 48000 two/3d3ddaf8_nohash_2.wav
# 50000 house/7e843da8_nohash_2.wav
# 52000 down/cc6bae0d_nohash_0.wav
# 54000 six/fb2f3242_nohash_0.wav
# 56000 yes/079dfce3_nohash_0.wav
# 58000 on/c0e0f834_nohash_0.wav
# 60000 five/98582fee_nohash_0.wav
# 62000 five/dd6c6806_nohash_1.wav
# 64000 off/c50225fa_nohash_3.wav
# 66000 four/9f4098cb_nohash_0.wav

# %%
train_dir = "./data/train/audio/"
test_dir = './data/test/audio/'
training_list, test_list = create_datastes_lists(train_dir , test_dir )

# %%
classes, classes_index, NB_CLASSES = read_classes(train_dir)
INPUT_SHAPE = X_train.shape[1:]
BATCH_SIZE = 64
WEIGHTS_DIR = "./"
inception = InceptionTimeClassifier(WEIGHTS_DIR, INPUT_SHAPE, NB_CLASSES, 1, batch_size=BATCH_SIZE, build=True)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 122, 85)]            0         []
#
#  conv1d (Conv1D)             (None, 122, 32)              2720      ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 122, 85)              0         ['input_1[0][0]']
#  D)
#
#  conv1d_1 (Conv1D)           (None, 122, 32)              40960     ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 122, 32)              20480     ['conv1d[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 122, 32)              10240     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 122, 32)              2720      ['max_pooling1d[0][0]']
#
#  concatenate (Concatenate)   (None, 122, 128)             0         ['conv1d_1[0][0]',
#                                                                      'conv1d_2[0][0]',
#                                                                      'conv1d_3[0][0]',
#                                                                      'conv1d_4[0][0]']
#
#  batch_normalization (Batch  (None, 122, 128)             512       ['concatenate[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 122, 128)             0         ['batch_normalization[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 122, 32)              4096      ['activation[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 122, 128)             0         ['activation[0][0]']
#  g1D)
#
#  conv1d_6 (Conv1D)           (None, 122, 32)              40960     ['conv1d_5[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 122, 32)              20480     ['conv1d_5[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 122, 32)              10240     ['conv1d_5[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 122, 32)              4096      ['max_pooling1d_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 122, 128)             0         ['conv1d_6[0][0]',
#  )                                                                   'conv1d_7[0][0]',
#                                                                      'conv1d_8[0][0]',
#                                                                      'conv1d_9[0][0]']
#
#  batch_normalization_1 (Bat  (None, 122, 128)             512       ['concatenate_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 122, 128)             0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_10 (Conv1D)          (None, 122, 32)              4096      ['activation_1[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 122, 128)             0         ['activation_1[0][0]']
#  g1D)
#
#  conv1d_11 (Conv1D)          (None, 122, 32)              40960     ['conv1d_10[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 122, 32)              20480     ['conv1d_10[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 122, 32)              10240     ['conv1d_10[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 122, 128)             0         ['conv1d_11[0][0]',
#  )                                                                   'conv1d_12[0][0]',
#                                                                      'conv1d_13[0][0]',
#                                                                      'conv1d_14[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 122, 128)             10880     ['input_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 122, 128)             512       ['concatenate_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 122, 128)             512       ['conv1d_15[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 122, 128)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 122, 128)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'activation_2[0][0]']
#
#  activation_3 (Activation)   (None, 122, 128)             0         ['add[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 122, 32)              4096      ['activation_3[0][0]']
#
#  max_pooling1d_3 (MaxPoolin  (None, 122, 128)             0         ['activation_3[0][0]']
#  g1D)
#
#  conv1d_17 (Conv1D)          (None, 122, 32)              40960     ['conv1d_16[0][0]']
#
#  conv1d_18 (Conv1D)          (None, 122, 32)              20480     ['conv1d_16[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 122, 32)              10240     ['conv1d_16[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_3[0][0]']
#
#  concatenate_3 (Concatenate  (None, 122, 128)             0         ['conv1d_17[0][0]',
#  )                                                                   'conv1d_18[0][0]',
#                                                                      'conv1d_19[0][0]',
#                                                                      'conv1d_20[0][0]']
#
#  batch_normalization_4 (Bat  (None, 122, 128)             512       ['concatenate_3[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 122, 128)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv1d_21 (Conv1D)          (None, 122, 32)              4096      ['activation_4[0][0]']
#
#  max_pooling1d_4 (MaxPoolin  (None, 122, 128)             0         ['activation_4[0][0]']
#  g1D)
#
#  conv1d_22 (Conv1D)          (None, 122, 32)              40960     ['conv1d_21[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 122, 32)              20480     ['conv1d_21[0][0]']
#
#  conv1d_24 (Conv1D)          (None, 122, 32)              10240     ['conv1d_21[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_4[0][0]']
#
#  concatenate_4 (Concatenate  (None, 122, 128)             0         ['conv1d_22[0][0]',
#  )                                                                   'conv1d_23[0][0]',
#                                                                      'conv1d_24[0][0]',
#                                                                      'conv1d_25[0][0]']
#
#  batch_normalization_5 (Bat  (None, 122, 128)             512       ['concatenate_4[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 122, 128)             0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv1d_26 (Conv1D)          (None, 122, 32)              4096      ['activation_5[0][0]']
#
#  max_pooling1d_5 (MaxPoolin  (None, 122, 128)             0         ['activation_5[0][0]']
#  g1D)
#
#  conv1d_27 (Conv1D)          (None, 122, 32)              40960     ['conv1d_26[0][0]']
#
#  conv1d_28 (Conv1D)          (None, 122, 32)              20480     ['conv1d_26[0][0]']
#
#  conv1d_29 (Conv1D)          (None, 122, 32)              10240     ['conv1d_26[0][0]']
#
#  conv1d_30 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_5[0][0]']
#
#  concatenate_5 (Concatenate  (None, 122, 128)             0         ['conv1d_27[0][0]',
#  )                                                                   'conv1d_28[0][0]',
#                                                                      'conv1d_29[0][0]',
#                                                                      'conv1d_30[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 122, 128)             16384     ['activation_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 122, 128)             512       ['concatenate_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 122, 128)             512       ['conv1d_31[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 122, 128)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 122, 128)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'activation_6[0][0]']
#
#  activation_7 (Activation)   (None, 122, 128)             0         ['add_1[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 122, 32)              4096      ['activation_7[0][0]']
#
#  max_pooling1d_6 (MaxPoolin  (None, 122, 128)             0         ['activation_7[0][0]']
#  g1D)
#
#  conv1d_33 (Conv1D)          (None, 122, 32)              40960     ['conv1d_32[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 122, 32)              20480     ['conv1d_32[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 122, 32)              10240     ['conv1d_32[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_6[0][0]']
#
#  concatenate_6 (Concatenate  (None, 122, 128)             0         ['conv1d_33[0][0]',
#  )                                                                   'conv1d_34[0][0]',
#                                                                      'conv1d_35[0][0]',
#                                                                      'conv1d_36[0][0]']
#
#  batch_normalization_8 (Bat  (None, 122, 128)             512       ['concatenate_6[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 122, 128)             0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv1d_37 (Conv1D)          (None, 122, 32)              4096      ['activation_8[0][0]']
#
#  max_pooling1d_7 (MaxPoolin  (None, 122, 128)             0         ['activation_8[0][0]']
#  g1D)
#
#  conv1d_38 (Conv1D)          (None, 122, 32)              40960     ['conv1d_37[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 122, 32)              20480     ['conv1d_37[0][0]']
#
#  conv1d_40 (Conv1D)          (None, 122, 32)              10240     ['conv1d_37[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_7[0][0]']
#
#  concatenate_7 (Concatenate  (None, 122, 128)             0         ['conv1d_38[0][0]',
#  )                                                                   'conv1d_39[0][0]',
#                                                                      'conv1d_40[0][0]',
#                                                                      'conv1d_41[0][0]']
#
#  batch_normalization_9 (Bat  (None, 122, 128)             512       ['concatenate_7[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 122, 128)             0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv1d_42 (Conv1D)          (None, 122, 32)              4096      ['activation_9[0][0]']
#
#  max_pooling1d_8 (MaxPoolin  (None, 122, 128)             0         ['activation_9[0][0]']
#  g1D)
#
#  conv1d_43 (Conv1D)          (None, 122, 32)              40960     ['conv1d_42[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 122, 32)              20480     ['conv1d_42[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 122, 32)              10240     ['conv1d_42[0][0]']
#
#  conv1d_46 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_8[0][0]']
#
#  concatenate_8 (Concatenate  (None, 122, 128)             0         ['conv1d_43[0][0]',
#  )                                                                   'conv1d_44[0][0]',
#                                                                      'conv1d_45[0][0]',
#                                                                      'conv1d_46[0][0]']
#
#  conv1d_47 (Conv1D)          (None, 122, 128)             16384     ['activation_7[0][0]']
#
#  batch_normalization_10 (Ba  (None, 122, 128)             512       ['concatenate_8[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 122, 128)             512       ['conv1d_47[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 122, 128)             0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 122, 128)             0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 122, 128)             0         ['add_2[0][0]']
#
#  conv1d_48 (Conv1D)          (None, 122, 32)              4096      ['activation_11[0][0]']
#
#  max_pooling1d_9 (MaxPoolin  (None, 122, 128)             0         ['activation_11[0][0]']
#  g1D)
#
#  conv1d_49 (Conv1D)          (None, 122, 32)              40960     ['conv1d_48[0][0]']
#
#  conv1d_50 (Conv1D)          (None, 122, 32)              20480     ['conv1d_48[0][0]']
#
#  conv1d_51 (Conv1D)          (None, 122, 32)              10240     ['conv1d_48[0][0]']
#
#  conv1d_52 (Conv1D)          (None, 122, 32)              4096      ['max_pooling1d_9[0][0]']
#
#  concatenate_9 (Concatenate  (None, 122, 128)             0         ['conv1d_49[0][0]',
#  )                                                                   'conv1d_50[0][0]',
#                                                                      'conv1d_51[0][0]',
#                                                                      'conv1d_52[0][0]']
#
#  batch_normalization_12 (Ba  (None, 122, 128)             512       ['concatenate_9[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 122, 128)             0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  global_average_pooling1d (  (None, 128)                  0         ['activation_12[0][0]']
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 31)                   3999      ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 850271 (3.24 MB)
# Trainable params: 846943 (3.23 MB)
# Non-trainable params: 3328 (13.00 KB)
# __________________________________________________________________________________________________

# %%
history = inception.fit(X_train, y_train, X_val, y_val)
# Out:
# accuracy
# 	training         	 (min:    0.813, max:    1.000, cur:    1.000)
# 	validation       	 (min:    0.802, max:    0.970, cur:    0.969)
# f1_score
# 	training         	 (min:    0.769, max:    1.000, cur:    1.000)
# 	validation       	 (min:    0.806, max:    0.972, cur:    0.971)
# Loss
# 	training         	 (min:    0.000, max:    0.725, cur:    0.001)
# 	validation       	 (min:    0.142, max:    0.825, cur:    0.209)
# lr
# 	lr               	 (min:    0.000, max:    0.001, cur:    0.000)
# precision
# 	training         	 (min:    0.938, max:    1.000, cur:    1.000)
# 	validation       	 (min:    0.830, max:    0.977, cur:    0.974)
# recall
# 	training         	 (min:    0.700, max:    1.000, cur:    1.000)
# 	validation       	 (min:    0.784, max:    0.969, cur:    0.969)
# 733/733 [==============================] - 72s 98ms/step - loss: 6.3133e-04 - accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - f1_score: 0.9999 - val_loss: 0.2087 - val_accuracy: 0.9695 - val_precision: 0.9743 - val_recall: 0.9687 - val_f1_score: 0.9715 - lr: 1.0000e-04
# Epoch 52: early stopping
# Model take 4497.973192930222 S to train

# %%
for i in range(0, len(test_list), 10000):
    X_test = np.zeros([len(test_list[i:i+10000]), 122, 85])
    for ind, file in enumerate(test_list[i:i+10000]):
        if '.DS_Store' in file:
            continue
        try:
            X_test[ind] = make_spec(file, test_dir)
        except:
            print(ind, file)
            continue
    y_test = inception.model.predict(X_test, batch_size = 1000, verbose = 1)
    y_test_ = [classes_index[letter] for letter in np.argmax(y_test, axis=1)]
    # y_test_ = [f if f in ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'silence'] else 'unknown' for f in y_test_]
    df = pd.DataFrame({'fname':test_list[i:i+10000], 'label':y_test_})
    df.to_csv('./y_test3.csv', mode='a', index=False, header=False)
# Out:
# /Users/zuzannaglinka/DeepLearning/2024Z_DeepLearning/P2_Transformers_Speech_Classification/prepare_data.py:26: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(sig[:16000],
# 10/10 [==============================] - 4s 141ms/step
# 10/10 [==============================] - 1s 148ms/step
# 10/10 [==============================] - 1s 144ms/step
# 10/10 [==============================] - 1s 150ms/step
# 10/10 [==============================] - 1s 144ms/step
# 10/10 [==============================] - 1s 144ms/step
# 10/10 [==============================] - 1s 137ms/step
# 10/10 [==============================] - 1s 137ms/step
# 10/10 [==============================] - 1s 136ms/step
# 10/10 [==============================] - 1s 144ms/step
# 10/10 [==============================] - 1s 147ms/step
# 10/10 [==============================] - 1s 147ms/step
# 10/10 [==============================] - 1s 147ms/step
# 10/10 [==============================] - 1s 146ms/step
# 10/10 [==============================] - 1s 147ms/step
# 9/9 [==============================] - 4s 234ms/step

# %%
y_hat = inception.model.predict(X_val, batch_size = BATCH_SIZE, verbose = 1)
y_hat_ = [classes_index[letter] for letter in np.argmax(y_hat, axis=1)]
y_val_ = [classes_index[letter] for letter in np.argmax(y_val, axis=1)]
# Out:
# 314/314 [==============================] - 8s 20ms/step

# %%
conf_mat = confusion_matrix(y_val_, y_hat_, labels=classes)
df = pd.DataFrame(conf_mat, index=classes, columns=classes)

# %%
show_confusion_matrix(df)
