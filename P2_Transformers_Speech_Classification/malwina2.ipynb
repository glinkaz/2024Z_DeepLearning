# %%
import torch
import librosa
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
import os

# %% [markdown]
# # Dla jednego pliku

# %%
# Initialize the Wav2Vec2 processor and model
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# Define the audio file path
audio_file_path = 'data/train/audio/happy/0ab3b47d_nohash_0.wav'  # Replace with your audio file path

# Load the audio file
audio, rate = librosa.load(audio_file_path, sr=16000)  # Wav2Vec2 expects 16kHz sample rate

# Preprocess the audio file
inputs = processor(audio, return_tensors="pt", padding=True, sampling_rate=16000)

# Make the prediction
logits = model(**inputs).logits

# Compute the predicted IDs
predicted_ids = torch.argmax(logits, dim=-1)

# Decode the IDs to get the transcription
transcription = processor.decode(predicted_ids[0])

print(f"Transcription for {audio_file_path}: {transcription}")
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Transcription for data/train/audio/happy/0ab3b47d_nohash_0.wav: HAPPY

# %%
# Extract the label from the file path
real_label = os.path.basename(os.path.dirname(audio_file_path))

print(f"Real label for {audio_file_path}: {real_label}")
# Out:
# Real label for data/train/audio/happy/0ab3b47d_nohash_0.wav: happy

# %% [markdown]
# Dla 2 folderów:

# %%
# Define the directory paths for 'bed' and 'bird'
dirs = ['data/train/audio/bed', 'data/train/audio/bird']

# Traverse through the specified directories
for data_dir in dirs:
    # Ensure the directory is indeed a directory
    if os.path.isdir(data_dir):
        # List all files in the directory
        all_files = os.listdir(data_dir)

        # Filter out the audio files
        audio_files = [file for file in all_files if file.endswith('.wav')]

        # Load and preprocess the audio files
        for audio_file in audio_files:
            audio_path = os.path.join(data_dir, audio_file)
            audio, rate = librosa.load(audio_path, sr=16000)  # Wav2Vec2 expects 16kHz sample rate
            inputs = processor(audio, return_tensors="pt", padding=True, sampling_rate=16000)
            logits = model(**inputs).logits

            # Compute the predicted IDs
            predicted_ids = torch.argmax(logits, dim=-1)

            # Decode the IDs to get the transcription
            transcription = processor.decode(predicted_ids[0])

            print(f"Transcription for {audio_file}: {transcription}")

            # Extract the label from the file path
            real_label = os.path.basename(os.path.dirname(audio_path))

            print(f"Real label for {audio_file}: {real_label}")
# Out:
# Transcription for 00176480_nohash_0.wav: BED
# Real label for 00176480_nohash_0.wav: bed
# Transcription for 004ae714_nohash_0.wav: BAYARD
# Real label for 004ae714_nohash_0.wav: bed
# Transcription for 004ae714_nohash_1.wav: BAOT
# Real label for 004ae714_nohash_1.wav: bed
# Transcription for 00f0204f_nohash_0.wav: BED
# Real label for 00f0204f_nohash_0.wav: bed
# Transcription for 00f0204f_nohash_1.wav: BAD
# Real label for 00f0204f_nohash_1.wav: bed
# Transcription for 012c8314_nohash_0.wav: BED
# Real label for 012c8314_nohash_0.wav: bed
# Transcription for 012c8314_nohash_1.wav: BED
# Real label for f19c1390_nohash_0.wav: bird
# Transcription for f1b35ace_nohash_0.wav: FIRIT
# Real label for f1b35ace_nohash_0.wav: bird
# Transcription for f1b35ace_nohash_1.wav: HIRED
# Real label for f1b35ace_nohash_1.wav: bird
# Transcription for f1b35ace_nohash_2.wav: FARD
# Real label for f1b35ace_nohash_2.wav: bird
# Transcription for f1d36c53_nohash_0.wav: IRD
# Real label for f1d36c53_nohash_0.wav: bird
# Transcription for f1d36c53_nohash_1.wav: BIRD
# Real label for f1d36c53_nohash_1.wav: bird
# Transcription for f292725f_nohash_0.wav: BIRD
# Real label for f292725f_nohash_0.wav: bird
# Transcription for f292725f_nohash_1.wav: BIRD
# Real label for f292725f_nohash_1.wav: bird
# Transcription for f297e878_nohash_0.wav: HERD
# Real label for f297e878_nohash_0.wav: bird
# Transcription for f2b8fc18_nohash_0.wav: BIRD
# Real label for f2b8fc18_nohash_0.wav: bird
# Transcription for f2b8fc18_nohash_1.wav: BIRD
# Real label for f2b8fc18_nohash_1.wav: bird
# Transcription for f2b8fc18_nohash_2.wav: BIRD
# Real label for f2b8fc18_nohash_2.wav: bird
# Transcription for f2dd248e_nohash_0.wav: BIRD
# Real label for f2dd248e_nohash_0.wav: bird
# Transcription for f33660af_nohash_0.wav: BIRD
# Real label for f33660af_nohash_0.wav: bird
# Transcription for f33660af_nohash_1.wav: BIR
# Real label for f33660af_nohash_1.wav: bird
# Transcription for f33660af_nohash_2.wav: BIRD
# Real label for f33660af_nohash_2.wav: bird
# Transcription for f34e6f44_nohash_0.wav: PIRATE
# Real label for f34e6f44_nohash_0.wav: bird
# Transcription for f35eedd7_nohash_0.wav: BIRD
# Real label for f35eedd7_nohash_0.wav: bird
# Transcription for f3957e23_nohash_0.wav: BARD
# Real label for f3957e23_nohash_0.wav: bird
# Transcription for f3cee168_nohash_0.wav: BIRD
# Real label for f3cee168_nohash_0.wav: bird
# Transcription for f3cee168_nohash_1.wav: BIRD
# Real label for f3cee168_nohash_1.wav: bird
# Transcription for f428ca69_nohash_0.wav: BIRD
# Real label for f428ca69_nohash_0.wav: bird
# Transcription for f42e234b_nohash_0.wav: BIRD
# Real label for f42e234b_nohash_0.wav: bird
# Transcription for f4386675_nohash_0.wav: THIRD
# Real label for f4386675_nohash_0.wav: bird
# Transcription for f4504600_nohash_0.wav: BIRD
# Real label for f4504600_nohash_0.wav: bird
# Transcription for f47d644e_nohash_0.wav: WOD
# Real label for f47d644e_nohash_0.wav: bird
# Transcription for f4c77b26_nohash_0.wav: BIRD
# Real label for f4c77b26_nohash_0.wav: bird
# Transcription for f4f59743_nohash_0.wav: BIRD
# Real label for f4f59743_nohash_0.wav: bird
# Transcription for f5496439_nohash_0.wav: BIRD
# Real label for f5496439_nohash_0.wav: bird
# Transcription for f5733968_nohash_0.wav: BERTS
# Real label for f5733968_nohash_0.wav: bird
# Transcription for f5c3de1b_nohash_0.wav: BIRD
# Real label for f5c3de1b_nohash_0.wav: bird
# Transcription for f5c3de1b_nohash_1.wav: BARDAN
# Real label for f5c3de1b_nohash_1.wav: bird
# Transcription for f5d09ebd_nohash_0.wav: BIRD
# Real label for f5d09ebd_nohash_0.wav: bird
# Transcription for f5d09ebd_nohash_1.wav: BIRD
# Real label for f5d09ebd_nohash_1.wav: bird
# Transcription for f5e5e8b0_nohash_0.wav: BIRD
# Real label for f5e5e8b0_nohash_0.wav: bird
# Transcription for f618568f_nohash_0.wav: IRD
# Real label for f618568f_nohash_0.wav: bird
# Transcription for f618568f_nohash_1.wav: BURD
# Real label for f618568f_nohash_1.wav: bird
# Transcription for f638a812_nohash_0.wav: BIRD
# Real label for f638a812_nohash_0.wav: bird
# Transcription for f63a6479_nohash_0.wav: BIRD
# Real label for f63a6479_nohash_0.wav: bird
# Transcription for f6581345_nohash_0.wav: BIRD
# Real label for f6581345_nohash_0.wav: bird
# Transcription for f6581345_nohash_1.wav: BIRD
# Real label for f6581345_nohash_1.wav: bird
# Transcription for f6581345_nohash_2.wav: BIRD
# Real label for f6581345_nohash_2.wav: bird
# Transcription for f6617a86_nohash_0.wav: BIRD
# Real label for f6617a86_nohash_0.wav: bird
# Transcription for f6617a86_nohash_1.wav: BIRD
# Real label for f6617a86_nohash_1.wav: bird
# Transcription for f6af2457_nohash_0.wav: BIRD
# Real label for f6af2457_nohash_0.wav: bird
# Transcription for f7879738_nohash_0.wav: BIRD
# Real label for f7879738_nohash_0.wav: bird
# Transcription for f804cbb3_nohash_0.wav: BIRD
# Real label for f804cbb3_nohash_0.wav: bird
# Transcription for f810e799_nohash_0.wav: MAR
# Real label for f810e799_nohash_0.wav: bird
# Transcription for f816db77_nohash_0.wav: BIRD
# Real label for f816db77_nohash_0.wav: bird
# Transcription for f839238a_nohash_0.wav: BIRD
# Real label for f839238a_nohash_0.wav: bird
# Transcription for f839238a_nohash_1.wav: BIRD
# Real label for f839238a_nohash_1.wav: bird
# Transcription for f852895b_nohash_0.wav: BIRD
# Real label for f852895b_nohash_0.wav: bird
# Transcription for f875f965_nohash_0.wav: HERD
# Real label for f875f965_nohash_0.wav: bird
# Transcription for f875f965_nohash_1.wav: BIRD
# Real label for f875f965_nohash_1.wav: bird
# Transcription for f88f97a7_nohash_0.wav: HERD
# Real label for f88f97a7_nohash_0.wav: bird
# Transcription for f8f60f59_nohash_0.wav: BURT
# Real label for f8f60f59_nohash_0.wav: bird
# Transcription for f9273a21_nohash_0.wav: BERG
# Real label for f9273a21_nohash_0.wav: bird
# Transcription for f9273a21_nohash_1.wav: BIRD
# Real label for f9273a21_nohash_1.wav: bird
# Transcription for f92e49f3_nohash_0.wav: BIRD
# Real label for f92e49f3_nohash_0.wav: bird
# Transcription for f9318c93_nohash_0.wav: BIRD
# Real label for f9318c93_nohash_0.wav: bird
# Transcription for f953e1af_nohash_0.wav: BED
# Real label for f953e1af_nohash_0.wav: bird
# Transcription for f97e1fcd_nohash_0.wav: BIRD
# Real label for f97e1fcd_nohash_0.wav: bird
# Transcription for f9af0887_nohash_0.wav: BIRD
# Real label for f9af0887_nohash_0.wav: bird
# Transcription for f9bdf10e_nohash_0.wav: BURIED
# Real label for f9bdf10e_nohash_0.wav: bird
# Transcription for f9ebdba0_nohash_0.wav: WOD
# Real label for f9ebdba0_nohash_0.wav: bird
# Transcription for f9f9751d_nohash_0.wav: BIRDE
# Real label for f9f9751d_nohash_0.wav: bird
# Transcription for f9f9751d_nohash_1.wav: BIRD
# Real label for f9f9751d_nohash_1.wav: bird
# Transcription for fa446c16_nohash_0.wav: BIRD
# Real label for fa446c16_nohash_0.wav: bird
# Transcription for fa446c16_nohash_1.wav: BIRD
# Real label for fa446c16_nohash_1.wav: bird
# Transcription for fa7895de_nohash_0.wav: BIRD
# Real label for fa7895de_nohash_0.wav: bird
# Transcription for fa7895de_nohash_1.wav: BIRD
# Real label for fa7895de_nohash_1.wav: bird
# Transcription for fac74f6a_nohash_0.wav: BURG
# Real label for fac74f6a_nohash_0.wav: bird
# Transcription for fac7deca_nohash_0.wav: BERD
# Real label for fac7deca_nohash_0.wav: bird
# Transcription for fad7a69a_nohash_0.wav: BIRD
# Real label for fad7a69a_nohash_0.wav: bird
# Transcription for fad7a69a_nohash_1.wav: BIRD
# Real label for fad7a69a_nohash_1.wav: bird
# Transcription for fafe8101_nohash_0.wav: BIRD
# Real label for fafe8101_nohash_0.wav: bird
# Transcription for fb2f3242_nohash_0.wav: BIRD
# Real label for fb2f3242_nohash_0.wav: bird
# Transcription for fb7c9b3b_nohash_0.wav: BIRD
# Real label for fb7c9b3b_nohash_0.wav: bird
# Transcription for fb9d6d23_nohash_0.wav: BIRD
# Real label for fb9d6d23_nohash_0.wav: bird
# Transcription for fbdc07bb_nohash_0.wav: BIRD
# Real label for fbdc07bb_nohash_0.wav: bird
# Transcription for fbe51750_nohash_0.wav: BIRD
# Real label for fbe51750_nohash_0.wav: bird
# Transcription for fbf3dd31_nohash_0.wav: BIRD
# Real label for fbf3dd31_nohash_0.wav: bird
# Transcription for fbf3dd31_nohash_1.wav: BIRD
# Real label for fbf3dd31_nohash_1.wav: bird
# Transcription for fc94edb0_nohash_0.wav: BIRD
# Real label for fc94edb0_nohash_0.wav: bird
# Transcription for fc94edb0_nohash_1.wav: BIRD
# Real label for fc94edb0_nohash_1.wav: bird
# Transcription for fce65496_nohash_0.wav: THIRD
# Real label for fce65496_nohash_0.wav: bird
# Transcription for fd395b74_nohash_0.wav:
# Real label for fd395b74_nohash_0.wav: bird
# Transcription for fda46b78_nohash_0.wav: BIRD
# Real label for fda46b78_nohash_0.wav: bird
# Transcription for fda46b78_nohash_1.wav: BIRD
# Real label for fda46b78_nohash_1.wav: bird
# Transcription for fda46b78_nohash_2.wav: THIRD
# Real label for fda46b78_nohash_2.wav: bird
# Transcription for fde2dee7_nohash_0.wav: BIR
# Real label for fde2dee7_nohash_0.wav: bird
# Transcription for fde2dee7_nohash_1.wav: BIRD
# Real label for fde2dee7_nohash_1.wav: bird
# Transcription for fe291fa9_nohash_0.wav: BIRD
# Real label for fe291fa9_nohash_0.wav: bird
# Transcription for fe291fa9_nohash_1.wav: BIRD
# Real label for fe291fa9_nohash_1.wav: bird
# Transcription for fe5c4a7a_nohash_0.wav: BIRD
# Real label for fe5c4a7a_nohash_0.wav: bird
# Transcription for fe5c4a7a_nohash_1.wav: BIRD
# Real label for fe5c4a7a_nohash_1.wav: bird
# Transcription for ff63ab0b_nohash_0.wav: BAR
# Real label for ff63ab0b_nohash_0.wav: bird
# Transcription for ff63ab0b_nohash_1.wav: BAR
# Real label for ff63ab0b_nohash_1.wav: bird
# Transcription for ff63ab0b_nohash_2.wav: BUR
# Real label for ff63ab0b_nohash_2.wav: bird
# Transcription for ffa76c4a_nohash_0.wav: BARN
# Real label for ffa76c4a_nohash_0.wav: bird
# Transcription for ffb86d3c_nohash_0.wav: BIRD
# Real label for ffb86d3c_nohash_0.wav: bird
# Transcription for ffb86d3c_nohash_1.wav: BIRD
# Real label for ffb86d3c_nohash_1.wav: bird
# Transcription for ffd2ba2f_nohash_0.wav: BIRD
# Real label for ffd2ba2f_nohash_0.wav: bird

# %%
# Initialize a counter for the correct predictions
correct_predictions = 0
total_predictions = 0
dirs = ['data/train/audio/bed', 'data/train/audio/bird']
# Traverse through the specified directories
for data_dir in dirs:
    # Ensure the directory is indeed a directory
    if os.path.isdir(data_dir):
        # List all files in the directory
        all_files = os.listdir(data_dir)

        # Filter out the audio files
        audio_files = [file for file in all_files if file.endswith('.wav')]

        # Load and preprocess the audio files
        for audio_file in audio_files:
            audio_path = os.path.join(data_dir, audio_file)
            audio, rate = librosa.load(audio_path, sr=16000)  # Wav2Vec2 expects 16kHz sample rate
            inputs = processor(audio, return_tensors="pt", padding=True, sampling_rate=16000)
            logits = model(**inputs).logits

            # Compute the predicted IDs
            predicted_ids = torch.argmax(logits, dim=-1)

            # Decode the IDs to get the transcription
            transcription = processor.decode(predicted_ids[0])

            # Convert the transcription to lowercase
            transcription = transcription.lower()

            # Extract the label from the file path
            real_label = os.path.basename(os.path.dirname(audio_path))

            # Convert the real label to lowercase
            real_label = real_label.lower()

            # Check if the prediction is correct
            if transcription == real_label:
                correct_predictions += 1

            total_predictions += 1

# Compute the accuracy
accuracy = correct_predictions / total_predictions

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.6187572590011614

# %%
import Levenshtein

# Lista dostępnych etykiet
available_labels = ["happy", "sad", "angry", "neutral", "excited"]

# Wynik klasyfikacji
classification_result = "happu"

# Znajdź najbliższe słowo na podstawie minimalnej odległości Levenshteina
closest_label = min(available_labels, key=lambda label: Levenshtein.distance(label, classification_result))

print("Closest label:", closest_label)
# Out:
# Closest label: happy

# %%
distances = {label: Levenshtein.distance(label, classification_result) for label in available_labels}

# Wydrukuj odległości
for label, distance in distances.items():
    print(f"Distance to {label}: {distance}")
# Out:
# Distance to happy: 1
# Distance to sad: 4
# Distance to angry: 5
# Distance to neutral: 7
# Distance to excited: 7

# %%
import os

# Ścieżka do folderu audio
audio_dir = 'data/train/audio'

# Pobierz wszystkie podkatalogi w folderze audio
all_subdirs = os.listdir(audio_dir)

# Filtruj tylko katalogi (pomijając pliki)
available_labels = [dir_name for dir_name in all_subdirs if os.path.isdir(os.path.join(audio_dir, dir_name))]


# Initialize a counter for the correct predictions
correct_predictions = 0
total_predictions = 0
dirs = ['data/train/audio/bed', 'data/train/audio/bird']

# Threshold for Levenshtein distance
levenshtein_threshold = 2  # Adjust this value based on your requirements

# Traverse through the specified directories
for data_dir in dirs:
    # Ensure the directory is indeed a directory
    if os.path.isdir(data_dir):
        # List all files in the directory
        all_files = os.listdir(data_dir)

        # Filter out the audio files
        audio_files = [file for file in all_files if file.endswith('.wav')]

        # Load and preprocess the audio files
        for audio_file in audio_files:
            audio_path = os.path.join(data_dir, audio_file)
            audio, rate = librosa.load(audio_path, sr=16000)  # Wav2Vec2 expects 16kHz sample rate
            inputs = processor(audio, return_tensors="pt", padding=True, sampling_rate=16000)
            logits = model(**inputs).logits

            # Compute the predicted IDs
            predicted_ids = torch.argmax(logits, dim=-1)

            # Decode the IDs to get the transcription
            transcription = processor.decode(predicted_ids[0])

            # Convert the transcription to lowercase
            transcription = transcription.lower()

            # Find the closest label based on Levenshtein distance
            closest_label = min(available_labels, key=lambda label: Levenshtein.distance(label, transcription))

            # If the Levenshtein distance is above the threshold, predict 'unknown'
            if Levenshtein.distance(closest_label, transcription) > levenshtein_threshold:
                closest_label = 'unknown'

            # Extract the label from the file path
            real_label = os.path.basename(os.path.dirname(audio_path))
            
            print(f"Predicted label for {audio_file}: {closest_label}")
            print(f"Real label for {audio_file}: {real_label}")

            # Convert the real label to lowercase
            real_label = real_label.lower()

            # Check if the prediction is correct
            if closest_label == real_label:
                correct_predictions += 1

            total_predictions += 1

# Compute the accuracy
accuracy = correct_predictions / total_predictions

print(f"Accuracy: {accuracy}")
# Out:
# Predicted label for 00176480_nohash_0.wav: bed
# Real label for 00176480_nohash_0.wav: bed
# Predicted label for 004ae714_nohash_0.wav: unknown
# Real label for 004ae714_nohash_0.wav: bed
# Predicted label for 004ae714_nohash_1.wav: cat
# Real label for 004ae714_nohash_1.wav: bed
# Predicted label for 00f0204f_nohash_0.wav: bed
# Real label for 00f0204f_nohash_0.wav: bed
# Predicted label for 00f0204f_nohash_1.wav: bed
# Real label for 00f0204f_nohash_1.wav: bed
# Predicted label for 012c8314_nohash_0.wav: bed
# Real label for 012c8314_nohash_0.wav: bed
# Predicted label for 012c8314_nohash_1.wav: bed
# Real label for 012c8314_nohash_1.wav: bed
# Predicted label for 0132a06d_nohash_0.wav: bed
# Real label for 0132a06d_nohash_0.wav: bed
# Predicted label for 0135f3f2_nohash_0.wav: bed
# Real label for 0135f3f2_nohash_0.wav: bed
# Predicted label for 0137b3f4_nohash_0.wav: cat
# Real label for 0137b3f4_nohash_0.wav: bed
# Predicted label for 014f9f65_nohash_0.wav: bed
# Real label for 014f9f65_nohash_0.wav: bed
# Predicted label for 01648c51_nohash_0.wav: bed
# Real label for 01648c51_nohash_0.wav: bed
# Predicted label for 01648c51_nohash_1.wav: bed
# Real label for 01648c51_nohash_1.wav: bed
# Predicted label for 016e2c6d_nohash_0.wav: bed
# Real label for 016e2c6d_nohash_0.wav: bed
# Predicted label for 01b4757a_nohash_0.wav: bed
# Real label for 01b4757a_nohash_0.wav: bed
# Predicted label for 01b4757a_nohash_1.wav: bed
# Real label for 01b4757a_nohash_1.wav: bed
# Predicted label for 01bcfc0c_nohash_0.wav: bed
# Real label for 01bcfc0c_nohash_0.wav: bed
# Predicted label for 0227998e_nohash_0.wav: bed
# Real label for 0227998e_nohash_0.wav: bed
# Predicted label for 026290a7_nohash_0.wav: bed
# Real label for 026290a7_nohash_0.wav: bed
# Predicted label for 02746d24_nohash_0.wav: bed
# Real label for 02746d24_nohash_0.wav: bed
# Predicted label for 035de8fe_nohash_0.wav: bed
# Real label for 035de8fe_nohash_0.wav: bed
# Predicted label for 0362539c_nohash_0.wav: bed
# Real label for 0362539c_nohash_0.wav: bed
# Predicted label for 0362539c_nohash_1.wav: bed
# Real label for 0362539c_nohash_1.wav: bed
# Predicted label for 037c445a_nohash_0.wav: bed
# Real label for 037c445a_nohash_0.wav: bed
# Predicted label for 0397ecda_nohash_0.wav: bed
# Real label for 0397ecda_nohash_0.wav: bed
# Predicted label for 03c96658_nohash_0.wav: bed
# Real label for 03c96658_nohash_0.wav: bed
# Predicted label for 042186b8_nohash_0.wav: bed
# Real label for 042186b8_nohash_0.wav: bed
# Predicted label for 042ea76c_nohash_0.wav: bed
# Real label for 042ea76c_nohash_0.wav: bed
# Predicted label for 0447d7c1_nohash_0.wav: bed
# Real label for 0447d7c1_nohash_0.wav: bed
# Predicted label for 0474c92a_nohash_0.wav: bed
# Real label for 0474c92a_nohash_0.wav: bed
# Predicted label for 0474c92a_nohash_1.wav: bed
# Real label for 0474c92a_nohash_1.wav: bed
# Predicted label for 05739450_nohash_0.wav: bed
# Real label for 05739450_nohash_0.wav: bed
# Predicted label for 05b2db80_nohash_0.wav: go
# Real label for 05b2db80_nohash_0.wav: bed
# Predicted label for 05d18852_nohash_0.wav: bed
# Real label for 05d18852_nohash_0.wav: bed
# Predicted label for 06076b6b_nohash_0.wav: bed
# Real label for 06076b6b_nohash_0.wav: bed
# Predicted label for 060cd039_nohash_0.wav: bed
# Real label for 060cd039_nohash_0.wav: bed
# Predicted label for 060cd039_nohash_1.wav: bed
# Real label for 060cd039_nohash_1.wav: bed
# Predicted label for 063d48cf_nohash_0.wav: bed
# Real label for 063d48cf_nohash_0.wav: bed
# Predicted label for 063d48cf_nohash_1.wav: bed
# Real label for 063d48cf_nohash_1.wav: bed
# Predicted label for 0685264e_nohash_0.wav: bed
# Real label for 0685264e_nohash_0.wav: bed
# Predicted label for 07363607_nohash_0.wav: bed
# Real label for 07363607_nohash_0.wav: bed
# Predicted label for 079dfce3_nohash_0.wav: bed
# Real label for 079dfce3_nohash_0.wav: bed
# Predicted label for 079dfce3_nohash_1.wav: bed
# Real label for 079dfce3_nohash_1.wav: bed
# Predicted label for 079dfce3_nohash_2.wav: bed
# Real label for 079dfce3_nohash_2.wav: bed
# Predicted label for 07c5129e_nohash_0.wav: bed
# Real label for 07c5129e_nohash_0.wav: bed
# Predicted label for 099d52ad_nohash_0.wav: bed
# Real label for 099d52ad_nohash_0.wav: bed
# Predicted label for 09bcdc9d_nohash_0.wav: bed
# Real label for 09bcdc9d_nohash_0.wav: bed
# Predicted label for 09bcdc9d_nohash_1.wav: bed
# Real label for 09bcdc9d_nohash_1.wav: bed
# Predicted label for 09ddc105_nohash_0.wav: bed
# Real label for 09ddc105_nohash_0.wav: bed
# Predicted label for 09ddc105_nohash_1.wav: bed
# Real label for 09ddc105_nohash_1.wav: bed
# Predicted label for 0a7c2a8d_nohash_0.wav: bed
# Real label for 0a7c2a8d_nohash_0.wav: bed
# Predicted label for 0b09edd3_nohash_0.wav: bed
# Real label for 0b09edd3_nohash_0.wav: bed
# Predicted label for 0b56bcfe_nohash_0.wav: bed
# Real label for 0b56bcfe_nohash_0.wav: bed
# Predicted label for 0b77ee66_nohash_0.wav: bed
# Real label for 0b77ee66_nohash_0.wav: bed
# Predicted label for 0b77ee66_nohash_1.wav: bed
# Real label for 0b77ee66_nohash_1.wav: bed
# Predicted label for 0b77ee66_nohash_2.wav: bed
# Real label for 0b77ee66_nohash_2.wav: bed
# Predicted label for 0bde966a_nohash_0.wav: three
# Real label for 0bde966a_nohash_0.wav: bed
# Predicted label for 0bde966a_nohash_1.wav: bed
# Real label for 0bde966a_nohash_1.wav: bed
# Predicted label for 0c2ca723_nohash_0.wav: bed
# Real label for 0c2ca723_nohash_0.wav: bed
# Predicted label for 0c2ca723_nohash_1.wav: bed
# Real label for 0c2ca723_nohash_1.wav: bed
# Predicted label for 0c2d2ffa_nohash_0.wav: bed
# Real label for 0c2d2ffa_nohash_0.wav: bed
# Predicted label for 0c2d2ffa_nohash_1.wav: bed
# Real label for 0c2d2ffa_nohash_1.wav: bed
# Predicted label for 0c40e715_nohash_0.wav: bed
# Real label for 0c40e715_nohash_0.wav: bed
# Predicted label for 0d2bcf9d_nohash_0.wav: bed
# Real label for 0d2bcf9d_nohash_0.wav: bed
# Predicted label for 0d2bcf9d_nohash_1.wav: bed
# Real label for 0d2bcf9d_nohash_1.wav: bed
# Predicted label for 0d393936_nohash_0.wav: bed
# Real label for 0d393936_nohash_0.wav: bed
# Predicted label for 0e17f595_nohash_0.wav: bed
# Real label for 0e17f595_nohash_0.wav: bed
# Predicted label for 0e17f595_nohash_1.wav: bed
# Real label for 0e17f595_nohash_1.wav: bed
# Predicted label for 0e5193e6_nohash_0.wav: bed
# Real label for 0e5193e6_nohash_0.wav: bed
# Predicted label for 0ea0e2f4_nohash_0.wav: bed
# Real label for 0ea0e2f4_nohash_0.wav: bed
# Predicted label for 0ea0e2f4_nohash_1.wav: bed
# Real label for 0ea0e2f4_nohash_1.wav: bed
# Predicted label for 0f7dc557_nohash_0.wav: bed
# Real label for 0f7dc557_nohash_0.wav: bed
# Predicted label for 0ff728b5_nohash_0.wav: bed
# Real label for 0ff728b5_nohash_0.wav: bed
# Predicted label for 102192fd_nohash_0.wav: bed
# Real label for 102192fd_nohash_0.wav: bed
# Predicted label for 10467b06_nohash_0.wav: bed
# Real label for 10467b06_nohash_0.wav: bed
# Predicted label for 105a0eea_nohash_0.wav: bed
# Real label for 105a0eea_nohash_0.wav: bed
# Predicted label for 105e72bb_nohash_0.wav: bed
# Real label for 105e72bb_nohash_0.wav: bed
# Predicted label for 10627519_nohash_0.wav: bed
# Real label for 10627519_nohash_0.wav: bed
# Predicted label for 106a6183_nohash_0.wav: bed
# Real label for 106a6183_nohash_0.wav: bed
# Predicted label for 10ace7eb_nohash_0.wav: bed
# Real label for 10ace7eb_nohash_0.wav: bed
# Predicted label for 10c6d873_nohash_0.wav: bed
# Real label for 10c6d873_nohash_0.wav: bed
# Predicted label for 11321027_nohash_0.wav: bed
# Real label for 11321027_nohash_0.wav: bed
# Predicted label for 118261a9_nohash_0.wav: bed
# Real label for 118261a9_nohash_0.wav: bed
# Predicted label for 118261a9_nohash_1.wav: bed
# Real label for 118261a9_nohash_1.wav: bed
# Predicted label for 118261a9_nohash_2.wav: bed
# Real label for 118261a9_nohash_2.wav: bed
# Predicted label for 11860c84_nohash_0.wav: bed
# Real label for 11860c84_nohash_0.wav: bed
# Predicted label for 11a022ba_nohash_0.wav: bed
# Real label for 11a022ba_nohash_0.wav: bed
# Predicted label for 11b1df78_nohash_0.wav: bed
# Real label for 11b1df78_nohash_0.wav: bed
# Predicted label for 11b1df78_nohash_1.wav: bed
# Real label for 11b1df78_nohash_1.wav: bed
# Predicted label for 122c5aa7_nohash_0.wav: bed
# Real label for 122c5aa7_nohash_0.wav: bed
# Predicted label for 12529547_nohash_0.wav: bed
# Real label for 12529547_nohash_0.wav: bed
# Predicted label for 126a31d2_nohash_0.wav: bed
# Real label for 126a31d2_nohash_0.wav: bed
# Predicted label for 129c7d8d_nohash_0.wav: bed
# Real label for 129c7d8d_nohash_0.wav: bed
# Predicted label for 13199b79_nohash_0.wav: bed
# Real label for 13199b79_nohash_0.wav: bed
# Predicted label for 1365dd89_nohash_0.wav: bed
# Real label for 1365dd89_nohash_0.wav: bed
# Predicted label for 1365dd89_nohash_1.wav: bed
# Real label for 1365dd89_nohash_1.wav: bed
# Predicted label for 146d97db_nohash_0.wav: bed
# Real label for 146d97db_nohash_0.wav: bed
# Predicted label for 14872d06_nohash_0.wav: bed
# Real label for 14872d06_nohash_0.wav: bed
# Predicted label for 14872d06_nohash_1.wav: bed
# Real label for 14872d06_nohash_1.wav: bed
# Predicted label for 14df1e28_nohash_0.wav: bed
# Real label for 14df1e28_nohash_0.wav: bed
# Predicted label for 1528225c_nohash_0.wav: bed
# Real label for 1528225c_nohash_0.wav: bed
# Predicted label for 1528225c_nohash_1.wav: bed
# Real label for 1528225c_nohash_1.wav: bed
# Predicted label for 1528225c_nohash_2.wav: bed
# Real label for 1528225c_nohash_2.wav: bed
# Predicted label for 1528225c_nohash_3.wav: bed
# Real label for 1528225c_nohash_3.wav: bed
# Predicted label for 15b0c947_nohash_0.wav: bed
# Real label for 15b0c947_nohash_0.wav: bed
# Predicted label for 15c371c7_nohash_0.wav: bed
# Real label for 15c371c7_nohash_0.wav: bed
# Predicted label for 15c563d7_nohash_0.wav: cat
# Real label for 15c563d7_nohash_0.wav: bed
# Predicted label for 15d83b54_nohash_0.wav: bed
# Real label for 15d83b54_nohash_0.wav: bed
# Predicted label for 15d83b54_nohash_1.wav: bed
# Real label for 15d83b54_nohash_1.wav: bed
# Predicted label for 15f04ff8_nohash_0.wav: bed
# Real label for 15f04ff8_nohash_0.wav: bed
# Predicted label for 161fcca8_nohash_0.wav: bed
# Real label for 161fcca8_nohash_0.wav: bed
# Predicted label for 161fcca8_nohash_1.wav: bed
# Real label for 161fcca8_nohash_1.wav: bed
# Predicted label for 1625acd8_nohash_0.wav: bed
# Real label for 1625acd8_nohash_0.wav: bed
# Predicted label for 1625acd8_nohash_1.wav: bed
# Real label for 1625acd8_nohash_1.wav: bed
# Predicted label for 1657c9fa_nohash_0.wav: bed
# Real label for 1657c9fa_nohash_0.wav: bed
# Predicted label for 16d41d07_nohash_0.wav: bed
# Real label for 16d41d07_nohash_0.wav: bed
# Predicted label for 16db1582_nohash_0.wav: bed
# Real label for 16db1582_nohash_0.wav: bed
# Predicted label for 1706c35f_nohash_0.wav: bed
# Real label for 1706c35f_nohash_0.wav: bed
# Predicted label for 1706c35f_nohash_1.wav: bed
# Real label for 1706c35f_nohash_1.wav: bed
# Predicted label for 1706c35f_nohash_2.wav: bed
# Real label for 1706c35f_nohash_2.wav: bed
# Predicted label for 1706c35f_nohash_3.wav: bed
# Real label for 1706c35f_nohash_3.wav: bed
# Predicted label for 171b56dc_nohash_0.wav: bed
# Real label for 171b56dc_nohash_0.wav: bed
# Predicted label for 172dc2b0_nohash_0.wav: bed
# Real label for 172dc2b0_nohash_0.wav: bed
# Predicted label for 172dc2b0_nohash_1.wav: bed
# Real label for 172dc2b0_nohash_1.wav: bed
# Predicted label for 172dc2b0_nohash_2.wav: bed
# Real label for 172dc2b0_nohash_2.wav: bed
# Predicted label for 173ae793_nohash_0.wav: bed
# Real label for 173ae793_nohash_0.wav: bed
# Predicted label for 173ae793_nohash_1.wav: bed
# Real label for 173ae793_nohash_1.wav: bed
# Predicted label for 173ce2be_nohash_0.wav: unknown
# Real label for 173ce2be_nohash_0.wav: bed
# Predicted label for 173ce2be_nohash_1.wav: bed
# Real label for 173ce2be_nohash_1.wav: bed
# Predicted label for 1746d7b6_nohash_0.wav: bed
# Real label for 1746d7b6_nohash_0.wav: bed
# Predicted label for 179a61b7_nohash_0.wav: unknown
# Real label for 179a61b7_nohash_0.wav: bed
# Predicted label for 17c94b23_nohash_0.wav: bed
# Real label for 17c94b23_nohash_0.wav: bed
# Predicted label for 17cc40ee_nohash_0.wav: bed
# Real label for 17cc40ee_nohash_0.wav: bed
# Predicted label for 17f0e206_nohash_0.wav: bed
# Real label for 17f0e206_nohash_0.wav: bed
# Predicted label for 17f0e206_nohash_1.wav: bed
# Real label for 17f0e206_nohash_1.wav: bed
# Predicted label for 187af8be_nohash_0.wav: bed
# Real label for 187af8be_nohash_0.wav: bed
# Predicted label for 1887fe04_nohash_0.wav: bed
# Real label for 1887fe04_nohash_0.wav: bed
# Predicted label for 1890e5c3_nohash_0.wav: bed
# Real label for 1890e5c3_nohash_0.wav: bed
# Predicted label for 18a1aab9_nohash_0.wav: bed
# Real label for 18a1aab9_nohash_0.wav: bed
# Predicted label for 18a8f03f_nohash_0.wav: bed
# Real label for 18a8f03f_nohash_0.wav: bed
# Predicted label for 18a8f03f_nohash_1.wav: bed
# Real label for 18a8f03f_nohash_1.wav: bed
# Predicted label for 18a8f03f_nohash_2.wav: bed
# Real label for 18a8f03f_nohash_2.wav: bed
# Predicted label for 18c54a68_nohash_0.wav: bed
# Real label for 18c54a68_nohash_0.wav: bed
# Predicted label for 18c54a68_nohash_1.wav: bed
# Real label for 18c54a68_nohash_1.wav: bed
# Predicted label for 18c54a68_nohash_2.wav: bed
# Real label for 18c54a68_nohash_2.wav: bed
# Predicted label for 18c54a68_nohash_3.wav: bed
# Real label for 18c54a68_nohash_3.wav: bed
# Predicted label for 18c54a68_nohash_4.wav: bed
# Real label for 18c54a68_nohash_4.wav: bed
# Predicted label for 190821dc_nohash_0.wav: bed
# Real label for 190821dc_nohash_0.wav: bed
# Predicted label for 1942abd7_nohash_0.wav: bed
# Real label for 1942abd7_nohash_0.wav: bed
# Predicted label for 19785c4e_nohash_0.wav: bed
# Real label for 19785c4e_nohash_0.wav: bed
# Predicted label for 19785c4e_nohash_1.wav: bed
# Real label for 19785c4e_nohash_1.wav: bed
# Predicted label for 19785c4e_nohash_2.wav: bed
# Real label for 19785c4e_nohash_2.wav: bed
# Predicted label for 1993db46_nohash_0.wav: bed
# Real label for 1993db46_nohash_0.wav: bed
# Predicted label for 1995cf9e_nohash_0.wav: bed
# Real label for 1995cf9e_nohash_0.wav: bed
# Predicted label for 19e246ad_nohash_0.wav: bed
# Real label for 19e246ad_nohash_0.wav: bed
# Predicted label for 19f9c115_nohash_0.wav: bed
# Real label for 19f9c115_nohash_0.wav: bed
# Predicted label for 19f9c115_nohash_1.wav: bed
# Real label for 19f9c115_nohash_1.wav: bed
# Predicted label for 19f9c115_nohash_2.wav: bed
# Real label for 19f9c115_nohash_2.wav: bed
# Predicted label for 19f9c115_nohash_3.wav: bed
# Real label for 19f9c115_nohash_3.wav: bed
# Predicted label for 1a073312_nohash_0.wav: bed
# Real label for 1a073312_nohash_0.wav: bed
# Predicted label for 1a073312_nohash_1.wav: bed
# Real label for 1a073312_nohash_1.wav: bed
# Predicted label for 1a4259c3_nohash_0.wav: bed
# Real label for 1a4259c3_nohash_0.wav: bed
# Predicted label for 1a4259c3_nohash_1.wav: bed
# Real label for 1a4259c3_nohash_1.wav: bed
# Predicted label for 1a5b9ca4_nohash_0.wav: bed
# Real label for 1a5b9ca4_nohash_0.wav: bed
# Predicted label for 1a5b9ca4_nohash_1.wav: bed
# Real label for 1a5b9ca4_nohash_1.wav: bed
# Predicted label for 1a673010_nohash_0.wav: bed
# Real label for 1a673010_nohash_0.wav: bed
# Predicted label for 1a6eca98_nohash_0.wav: bed
# Real label for 1a6eca98_nohash_0.wav: bed
# Predicted label for 1a6eca98_nohash_1.wav: bed
# Real label for 1a6eca98_nohash_1.wav: bed
# Predicted label for 1a892463_nohash_0.wav: bed
# Real label for 1a892463_nohash_0.wav: bed
# Predicted label for 1a9afd33_nohash_0.wav: bed
# Real label for 1a9afd33_nohash_0.wav: bed
# Predicted label for 1a9afd33_nohash_1.wav: bed
# Real label for 1a9afd33_nohash_1.wav: bed
# Predicted label for 1aed7c6d_nohash_0.wav: bed
# Real label for 1aed7c6d_nohash_0.wav: bed
# Predicted label for 1aed7c6d_nohash_1.wav: bed
# Real label for 1aed7c6d_nohash_1.wav: bed
# Predicted label for 1afd49bf_nohash_0.wav: bed
# Real label for 1afd49bf_nohash_0.wav: bed
# Predicted label for 1afd49bf_nohash_1.wav: bed
# Real label for 1afd49bf_nohash_1.wav: bed
# Predicted label for 1b459024_nohash_0.wav: bed
# Real label for 1b459024_nohash_0.wav: bed
# Predicted label for 1b4c9b89_nohash_0.wav: bed
# Real label for 1b4c9b89_nohash_0.wav: bed
# Predicted label for 1b63157b_nohash_0.wav: bed
# Real label for 1b63157b_nohash_0.wav: bed
# Predicted label for 1b755c65_nohash_0.wav: bed
# Real label for 1b755c65_nohash_0.wav: bed
# Predicted label for 1b755c65_nohash_1.wav: bed
# Real label for 1b755c65_nohash_1.wav: bed
# Predicted label for 1bb574f9_nohash_0.wav: bed
# Real label for 1bb574f9_nohash_0.wav: bed
# Predicted label for 1bb6ed89_nohash_0.wav: bed
# Real label for 1bb6ed89_nohash_0.wav: bed
# Predicted label for 1bb6ed89_nohash_1.wav: bed
# Real label for 1bb6ed89_nohash_1.wav: bed
# Predicted label for 1bc45db9_nohash_0.wav: one
# Real label for 1bc45db9_nohash_0.wav: bed
# Predicted label for 1c3f50ad_nohash_0.wav: bed
# Real label for 1c3f50ad_nohash_0.wav: bed
# Predicted label for 1c45ceb2_nohash_0.wav: bed
# Real label for 1c45ceb2_nohash_0.wav: bed
# Predicted label for 1c6e5447_nohash_0.wav: bed
# Real label for 1c6e5447_nohash_0.wav: bed
# Predicted label for 1cb788bc_nohash_0.wav: bed
# Real label for 1cb788bc_nohash_0.wav: bed
# Predicted label for 1cb788bc_nohash_1.wav: bed
# Real label for 1cb788bc_nohash_1.wav: bed
# Predicted label for 1cbcc7a7_nohash_0.wav: bed
# Real label for 1cbcc7a7_nohash_0.wav: bed
# Predicted label for 1d1fe0a0_nohash_0.wav: bed
# Real label for 1d1fe0a0_nohash_0.wav: bed
# Predicted label for 1dce06e8_nohash_0.wav: bed
# Real label for 1dce06e8_nohash_0.wav: bed
# Predicted label for 1df483c0_nohash_0.wav: bed
# Real label for 1df483c0_nohash_0.wav: bed
# Predicted label for 1df99a8a_nohash_0.wav: bed
# Real label for 1df99a8a_nohash_0.wav: bed
# Predicted label for 1df99a8a_nohash_1.wav: bed
# Real label for 1df99a8a_nohash_1.wav: bed
# Predicted label for 1e4064b8_nohash_0.wav: bed
# Real label for 1e4064b8_nohash_0.wav: bed
# Predicted label for 1e4064b8_nohash_1.wav: bed
# Real label for 1e4064b8_nohash_1.wav: bed
# Predicted label for 1e412fac_nohash_0.wav: bed
# Real label for 1e412fac_nohash_0.wav: bed
# Predicted label for 1ecfb537_nohash_0.wav: bed
# Real label for 1ecfb537_nohash_0.wav: bed
# Predicted label for 1ed557b9_nohash_0.wav: bed
# Real label for 1ed557b9_nohash_0.wav: bed
# Predicted label for 1ffd513b_nohash_0.wav: bed
# Real label for 1ffd513b_nohash_0.wav: bed
# Predicted label for 20174140_nohash_0.wav: bed
# Real label for 20174140_nohash_0.wav: bed
# Predicted label for 2039b9c1_nohash_0.wav: bed
# Real label for 2039b9c1_nohash_0.wav: bed
# Predicted label for 20d3f11f_nohash_0.wav: bed
# Real label for 20d3f11f_nohash_0.wav: bed
# Predicted label for 210f3aa9_nohash_0.wav: bed
# Real label for 210f3aa9_nohash_0.wav: bed
# Predicted label for 21307344_nohash_0.wav: bed
# Real label for 21307344_nohash_0.wav: bed
# Predicted label for 215699ff_nohash_0.wav: bed
# Real label for 215699ff_nohash_0.wav: bed
# Predicted label for 215699ff_nohash_1.wav: bed
# Real label for 215699ff_nohash_1.wav: bed
# Predicted label for 21832144_nohash_0.wav: bed
# Real label for 21832144_nohash_0.wav: bed
# Predicted label for 21cbe292_nohash_0.wav: bed
# Real label for 21cbe292_nohash_0.wav: bed
# Predicted label for 21e8c417_nohash_0.wav: bed
# Real label for 21e8c417_nohash_0.wav: bed
# Predicted label for 229978fd_nohash_0.wav: bed
# Real label for 229978fd_nohash_0.wav: bed
# Predicted label for 2313e093_nohash_0.wav: bed
# Real label for 2313e093_nohash_0.wav: bed
# Predicted label for 234ab0fb_nohash_0.wav: bed
# Real label for 234ab0fb_nohash_0.wav: bed
# Predicted label for 238c112c_nohash_0.wav: bed
# Real label for 238c112c_nohash_0.wav: bed
# Predicted label for 23abe1c9_nohash_0.wav: bed
# Real label for 23abe1c9_nohash_0.wav: bed
# Predicted label for 23ad12d8_nohash_0.wav: bed
# Real label for 23ad12d8_nohash_0.wav: bed
# Predicted label for 24b82192_nohash_0.wav: bed
# Real label for 24b82192_nohash_0.wav: bed
# Predicted label for 24befdb3_nohash_0.wav: bed
# Real label for 24befdb3_nohash_0.wav: bed
# Predicted label for 24ed94ab_nohash_0.wav: bed
# Real label for 24ed94ab_nohash_0.wav: bed
# Predicted label for 24ed94ab_nohash_1.wav: bed
# Real label for 24ed94ab_nohash_1.wav: bed
# Predicted label for 25040e85_nohash_0.wav: bed
# Real label for 25040e85_nohash_0.wav: bed
# Predicted label for 2510c044_nohash_0.wav: bed
# Real label for 2510c044_nohash_0.wav: bed
# Predicted label for 25132942_nohash_0.wav: bed
# Real label for 25132942_nohash_0.wav: bed
# Predicted label for 257e17e0_nohash_0.wav: bed
# Real label for 257e17e0_nohash_0.wav: bed
# Predicted label for 2589f361_nohash_0.wav: bed
# Real label for 2589f361_nohash_0.wav: bed
# Predicted label for 25c14394_nohash_0.wav: bed
# Real label for 25c14394_nohash_0.wav: bed
# Predicted label for 25c14394_nohash_1.wav: bed
# Real label for 25c14394_nohash_1.wav: bed
# Predicted label for 264f471d_nohash_0.wav: unknown
# Real label for 264f471d_nohash_0.wav: bed
# Predicted label for 26e573a9_nohash_0.wav: bed
# Real label for 26e573a9_nohash_0.wav: bed
# Predicted label for 26e9ae6b_nohash_0.wav: bed
# Real label for 26e9ae6b_nohash_0.wav: bed
# Predicted label for 26e9ae6b_nohash_1.wav: bed
# Real label for 26e9ae6b_nohash_1.wav: bed
# Predicted label for 26e9ae6b_nohash_2.wav: bed
# Real label for 26e9ae6b_nohash_2.wav: bed
# Predicted label for 270bfa52_nohash_0.wav: bed
# Real label for 270bfa52_nohash_0.wav: bed
# Predicted label for 274c008f_nohash_0.wav: bed
# Real label for 274c008f_nohash_0.wav: bed
# Predicted label for 2796ac50_nohash_0.wav: bed
# Real label for 2796ac50_nohash_0.wav: bed
# Predicted label for 27b03931_nohash_0.wav: bed
# Real label for 27b03931_nohash_0.wav: bed
# Predicted label for 27b9a84f_nohash_0.wav: bed
# Real label for 27b9a84f_nohash_0.wav: bed
# Predicted label for 283d7a53_nohash_0.wav: bed
# Real label for 283d7a53_nohash_0.wav: bed
# Predicted label for 28460a60_nohash_0.wav: bed
# Real label for 28460a60_nohash_0.wav: bed
# Predicted label for 28497c5b_nohash_0.wav: bed
# Real label for 28497c5b_nohash_0.wav: bed
# Predicted label for 28612180_nohash_0.wav: bed
# Real label for 28612180_nohash_0.wav: bed
# Predicted label for 28612180_nohash_1.wav: bed
# Real label for 28612180_nohash_1.wav: bed
# Predicted label for 28612180_nohash_2.wav: bed
# Real label for 28612180_nohash_2.wav: bed
# Predicted label for 28ce0c58_nohash_0.wav: unknown
# Real label for 28ce0c58_nohash_0.wav: bed
# Predicted label for 28e47b1a_nohash_0.wav: bed
# Real label for 28e47b1a_nohash_0.wav: bed
# Predicted label for 28ed6bc9_nohash_0.wav: bed
# Real label for 28ed6bc9_nohash_0.wav: bed
# Predicted label for 28ef2a01_nohash_0.wav: bed
# Real label for 28ef2a01_nohash_0.wav: bed
# Predicted label for 29fb33da_nohash_0.wav: bed
# Real label for 29fb33da_nohash_0.wav: bed
# Predicted label for 2a0b413e_nohash_0.wav: bed
# Real label for 2a0b413e_nohash_0.wav: bed
# Predicted label for 2a89ad5c_nohash_0.wav: bed
# Real label for 2a89ad5c_nohash_0.wav: bed
# Predicted label for 2aec99ec_nohash_0.wav: bed
# Real label for 2aec99ec_nohash_0.wav: bed
# Predicted label for 2aec99ec_nohash_1.wav: bed
# Real label for 2aec99ec_nohash_1.wav: bed
# Predicted label for 2b3f509b_nohash_0.wav: go
# Real label for 2b3f509b_nohash_0.wav: bed
# Predicted label for 2bd2cad5_nohash_0.wav: unknown
# Real label for 2bd2cad5_nohash_0.wav: bed
# Predicted label for 2bd2cad5_nohash_1.wav: bed
# Real label for 2bd2cad5_nohash_1.wav: bed
# Predicted label for 2bdbe5f7_nohash_0.wav: unknown
# Real label for 2bdbe5f7_nohash_0.wav: bed
# Predicted label for 2be08ce4_nohash_0.wav: bed
# Real label for 2be08ce4_nohash_0.wav: bed
# Predicted label for 2be08ce4_nohash_1.wav: bed
# Real label for 2be08ce4_nohash_1.wav: bed
# Predicted label for 2be08ce4_nohash_2.wav: bed
# Real label for 2be08ce4_nohash_2.wav: bed
# Predicted label for 2bfe70ef_nohash_0.wav: bed
# Real label for 2bfe70ef_nohash_0.wav: bed
# Predicted label for 2c6446f7_nohash_0.wav: bed
# Real label for 2c6446f7_nohash_0.wav: bed
# Predicted label for 2c6d3924_nohash_0.wav: bed
# Real label for 2c6d3924_nohash_0.wav: bed
# Predicted label for 2c7c33e8_nohash_0.wav: bed
# Real label for 2c7c33e8_nohash_0.wav: bed
# Predicted label for 2ce7534c_nohash_0.wav: bed
# Real label for 2ce7534c_nohash_0.wav: bed
# Predicted label for 2ce7534c_nohash_1.wav: bed
# Real label for 2ce7534c_nohash_1.wav: bed
# Predicted label for 2cf28b70_nohash_0.wav: bed
# Real label for 2cf28b70_nohash_0.wav: bed
# Predicted label for 2d82a556_nohash_0.wav: bed
# Real label for 2d82a556_nohash_0.wav: bed
# Predicted label for 2d82a556_nohash_1.wav: bed
# Real label for 2d82a556_nohash_1.wav: bed
# Predicted label for 2d92f18b_nohash_0.wav: bed
# Real label for 2d92f18b_nohash_0.wav: bed
# Predicted label for 2d92f18b_nohash_1.wav: bed
# Real label for 2d92f18b_nohash_1.wav: bed
# Predicted label for 2da58b32_nohash_0.wav: unknown
# Real label for 2da58b32_nohash_0.wav: bed
# Predicted label for 2dcb6848_nohash_0.wav: bed
# Real label for 2dcb6848_nohash_0.wav: bed
# Predicted label for 2dcb6848_nohash_1.wav: bed
# Real label for 2dcb6848_nohash_1.wav: bed
# Predicted label for 2f0a410b_nohash_0.wav: bed
# Real label for 2f0a410b_nohash_0.wav: bed
# Predicted label for 300384f0_nohash_0.wav: bed
# Real label for 300384f0_nohash_0.wav: bed
# Predicted label for 300384f0_nohash_1.wav: bed
# Real label for 300384f0_nohash_1.wav: bed
# Predicted label for 30065f33_nohash_0.wav: bed
# Real label for 30065f33_nohash_0.wav: bed
# Predicted label for 30065f33_nohash_1.wav: bed
# Real label for 30065f33_nohash_1.wav: bed
# Predicted label for 30137d34_nohash_0.wav: bed
# Real label for 30137d34_nohash_0.wav: bed
# Predicted label for 305776dd_nohash_0.wav: bed
# Real label for 305776dd_nohash_0.wav: bed
# Predicted label for 305776dd_nohash_1.wav: bed
# Real label for 305776dd_nohash_1.wav: bed
# Predicted label for 305776dd_nohash_2.wav: bed
# Real label for 305776dd_nohash_2.wav: bed
# Predicted label for 30802c5d_nohash_0.wav: bed
# Real label for 30802c5d_nohash_0.wav: bed
# Predicted label for 30a09789_nohash_0.wav: three
# Real label for 30a09789_nohash_0.wav: bed
# Predicted label for 30f31e42_nohash_0.wav: bed
# Real label for 30f31e42_nohash_0.wav: bed
# Predicted label for 311fde72_nohash_0.wav: bed
# Real label for 311fde72_nohash_0.wav: bed
# Predicted label for 31270cb2_nohash_0.wav: go
# Real label for 31270cb2_nohash_0.wav: bed
# Predicted label for 31270cb2_nohash_1.wav: bed
# Real label for 31270cb2_nohash_1.wav: bed
# Predicted label for 3143fdff_nohash_0.wav: bed
# Real label for 3143fdff_nohash_0.wav: bed
# Predicted label for 31583d30_nohash_0.wav: bed
# Real label for 31583d30_nohash_0.wav: bed
# Predicted label for 31583d30_nohash_1.wav: bed
# Real label for 31583d30_nohash_1.wav: bed
# Predicted label for 31583d30_nohash_2.wav: bed
# Real label for 31583d30_nohash_2.wav: bed
# Predicted label for 31d31fa0_nohash_0.wav: bed
# Real label for 31d31fa0_nohash_0.wav: bed
# Predicted label for 31d68957_nohash_0.wav: bed
# Real label for 31d68957_nohash_0.wav: bed
# Predicted label for 3209ec42_nohash_0.wav: bed
# Real label for 3209ec42_nohash_0.wav: bed
# Predicted label for 3209ec42_nohash_1.wav: bed
# Real label for 3209ec42_nohash_1.wav: bed
# Predicted label for 324210dd_nohash_0.wav: bed
# Real label for 324210dd_nohash_0.wav: bed
# Predicted label for 325a0c39_nohash_0.wav: bed
# Real label for 325a0c39_nohash_0.wav: bed
# Predicted label for 32efce64_nohash_0.wav: bed
# Real label for 32efce64_nohash_0.wav: bed
# Predicted label for 32efce64_nohash_1.wav: bed
# Real label for 32efce64_nohash_1.wav: bed
# Predicted label for 32efce64_nohash_2.wav: bed
# Real label for 32efce64_nohash_2.wav: bed
# Predicted label for 333784b7_nohash_0.wav: bed
# Real label for 333784b7_nohash_0.wav: bed
# Predicted label for 3389305e_nohash_0.wav: bed
# Real label for 3389305e_nohash_0.wav: bed
# Predicted label for 338dacf5_nohash_0.wav: bed
# Real label for 338dacf5_nohash_0.wav: bed
# Predicted label for 33903159_nohash_0.wav: bed
# Real label for 33903159_nohash_0.wav: bed
# Predicted label for 33f60c62_nohash_0.wav: bed
# Real label for 33f60c62_nohash_0.wav: bed
# Predicted label for 3402e488_nohash_0.wav: bed
# Real label for 3402e488_nohash_0.wav: bed
# Predicted label for 3411cf4b_nohash_0.wav: bed
# Real label for 3411cf4b_nohash_0.wav: bed
# Predicted label for 3411cf4b_nohash_1.wav: bed
# Real label for 3411cf4b_nohash_1.wav: bed
# Predicted label for 34263ab3_nohash_0.wav: unknown
# Real label for 34263ab3_nohash_0.wav: bed
# Predicted label for 34263ab3_nohash_1.wav: bed
# Real label for 34263ab3_nohash_1.wav: bed
# Predicted label for 34263ab3_nohash_2.wav: bed
# Real label for 34263ab3_nohash_2.wav: bed
# Predicted label for 34ba417a_nohash_0.wav: bed
# Real label for 34ba417a_nohash_0.wav: bed
# Predicted label for 34ba417a_nohash_1.wav: bed
# Real label for 34ba417a_nohash_1.wav: bed
# Predicted label for 34ba417a_nohash_2.wav: bed
# Real label for 34ba417a_nohash_2.wav: bed
# Predicted label for 34e8c726_nohash_0.wav: bed
# Real label for 34e8c726_nohash_0.wav: bed
# Predicted label for 34e8c726_nohash_1.wav: bed
# Real label for 34e8c726_nohash_1.wav: bed
# Predicted label for 353b4d33_nohash_0.wav: bed
# Real label for 353b4d33_nohash_0.wav: bed
# Predicted label for 3565ca83_nohash_0.wav: bed
# Real label for 3565ca83_nohash_0.wav: bed
# Predicted label for 35c8fa78_nohash_0.wav: bed
# Real label for 35c8fa78_nohash_0.wav: bed
# Predicted label for 35c8fa78_nohash_1.wav: bed
# Real label for 35c8fa78_nohash_1.wav: bed
# Predicted label for 35d1b6ee_nohash_0.wav: bed
# Real label for 35d1b6ee_nohash_0.wav: bed
# Predicted label for 36050ef3_nohash_0.wav: bed
# Real label for 36050ef3_nohash_0.wav: bed
# Predicted label for 364c0853_nohash_0.wav: bed
# Real label for 364c0853_nohash_0.wav: bed
# Predicted label for 364c0853_nohash_1.wav: bed
# Real label for 364c0853_nohash_1.wav: bed
# Predicted label for 365531e2_nohash_0.wav: bed
# Real label for 365531e2_nohash_0.wav: bed
# Predicted label for 36746d7f_nohash_0.wav: bed
# Real label for 36746d7f_nohash_0.wav: bed
# Predicted label for 36746d7f_nohash_1.wav: bed
# Real label for 36746d7f_nohash_1.wav: bed
# Predicted label for 370844f7_nohash_0.wav: bed
# Real label for 370844f7_nohash_0.wav: bed
# Predicted label for 37b03ab1_nohash_0.wav: bed
# Real label for 37b03ab1_nohash_0.wav: bed
# Predicted label for 37b03ab1_nohash_1.wav: bed
# Real label for 37b03ab1_nohash_1.wav: bed
# Predicted label for 37dca74f_nohash_0.wav: bed
# Real label for 37dca74f_nohash_0.wav: bed
# Predicted label for 37e8db82_nohash_0.wav: bed
# Real label for 37e8db82_nohash_0.wav: bed
# Predicted label for 38d78313_nohash_0.wav: bed
# Real label for 38d78313_nohash_0.wav: bed
# Predicted label for 3903b558_nohash_0.wav: bed
# Real label for 3903b558_nohash_0.wav: bed
# Predicted label for 39a12648_nohash_0.wav: unknown
# Real label for 39a12648_nohash_0.wav: bed
# Predicted label for 39a6b995_nohash_0.wav: bed
# Real label for 39a6b995_nohash_0.wav: bed
# Predicted label for 39c13eed_nohash_0.wav: bed
# Real label for 39c13eed_nohash_0.wav: bed
# Predicted label for 39dce8cc_nohash_0.wav: bed
# Real label for 39dce8cc_nohash_0.wav: bed
# Predicted label for 39ec87ac_nohash_0.wav: bed
# Real label for 39ec87ac_nohash_0.wav: bed
# Predicted label for 3a182c98_nohash_0.wav: bed
# Real label for 3a182c98_nohash_0.wav: bed
# Predicted label for 3a33d3a4_nohash_0.wav: left
# Real label for 3a33d3a4_nohash_0.wav: bed
# Predicted label for 3a789a0d_nohash_0.wav: bed
# Real label for 3a789a0d_nohash_0.wav: bed
# Predicted label for 3a7d8872_nohash_0.wav: bed
# Real label for 3a7d8872_nohash_0.wav: bed
# Predicted label for 3aa6f4e2_nohash_0.wav: bed
# Real label for 3aa6f4e2_nohash_0.wav: bed
# Predicted label for 3ab9ba07_nohash_0.wav: bed
# Real label for 3ab9ba07_nohash_0.wav: bed
# Predicted label for 3ac2e76f_nohash_0.wav: bed
# Real label for 3ac2e76f_nohash_0.wav: bed
# Predicted label for 3b852f6f_nohash_0.wav: bed
# Real label for 3b852f6f_nohash_0.wav: bed
# Predicted label for 3b852f6f_nohash_1.wav: unknown
# Real label for 3b852f6f_nohash_1.wav: bed
# Predicted label for 3b853f44_nohash_0.wav: bed
# Real label for 3b853f44_nohash_0.wav: bed
# Predicted label for 3bc21161_nohash_0.wav: bed
# Real label for 3bc21161_nohash_0.wav: bed
# Predicted label for 3bfd30e6_nohash_0.wav: cat
# Real label for 3bfd30e6_nohash_0.wav: bed
# Predicted label for 3c257192_nohash_0.wav: bed
# Real label for 3c257192_nohash_0.wav: bed
# Predicted label for 3c6d55b3_nohash_0.wav: bed
# Real label for 3c6d55b3_nohash_0.wav: bed
# Predicted label for 3c8dc702_nohash_0.wav: bed
# Real label for 3c8dc702_nohash_0.wav: bed
# Predicted label for 3ca784ec_nohash_0.wav: bed
# Real label for 3ca784ec_nohash_0.wav: bed
# Predicted label for 3cdecb0b_nohash_0.wav: bed
# Real label for 3cdecb0b_nohash_0.wav: bed
# Predicted label for 3cdecb0b_nohash_1.wav: bed
# Real label for 3cdecb0b_nohash_1.wav: bed
# Predicted label for 3cfc6b3a_nohash_0.wav: bed
# Real label for 3cfc6b3a_nohash_0.wav: bed
# Predicted label for 3d53244b_nohash_0.wav: bed
# Real label for 3d53244b_nohash_0.wav: bed
# Predicted label for 3d6bee47_nohash_0.wav: bed
# Real label for 3d6bee47_nohash_0.wav: bed
# Predicted label for 3da7f617_nohash_0.wav: bed
# Real label for 3da7f617_nohash_0.wav: bed
# Predicted label for 3df9a3d4_nohash_0.wav: go
# Real label for 3df9a3d4_nohash_0.wav: bed
# Predicted label for 3df9a3d4_nohash_1.wav: cat
# Real label for 3df9a3d4_nohash_1.wav: bed
# Predicted label for 3e31dffe_nohash_0.wav: bed
# Real label for 3e31dffe_nohash_0.wav: bed
# Predicted label for 3e3b65eb_nohash_0.wav: bed
# Real label for 3e3b65eb_nohash_0.wav: bed
# Predicted label for 3e3b65eb_nohash_1.wav: bed
# Real label for 3e3b65eb_nohash_1.wav: bed
# Predicted label for 3e3fa7fd_nohash_0.wav: bed
# Real label for 3e3fa7fd_nohash_0.wav: bed
# Predicted label for 3eb8764c_nohash_0.wav: bed
# Real label for 3eb8764c_nohash_0.wav: bed
# Predicted label for 3eb8764c_nohash_1.wav: bed
# Real label for 3eb8764c_nohash_1.wav: bed
# Predicted label for 3ec05c3d_nohash_0.wav: bed
# Real label for 3ec05c3d_nohash_0.wav: bed
# Predicted label for 3ed3e49a_nohash_0.wav: bed
# Real label for 3ed3e49a_nohash_0.wav: bed
# Predicted label for 3ed3e49a_nohash_1.wav: bed
# Real label for 3ed3e49a_nohash_1.wav: bed
# Predicted label for 3ed3e49a_nohash_2.wav: bed
# Real label for 3ed3e49a_nohash_2.wav: bed
# Predicted label for 3ed3e49a_nohash_3.wav: bed
# Real label for 3ed3e49a_nohash_3.wav: bed
# Predicted label for 3efa7ec4_nohash_0.wav: bed
# Real label for 3efa7ec4_nohash_0.wav: bed
# Predicted label for 3efa7ec4_nohash_1.wav: bed
# Real label for 3efa7ec4_nohash_1.wav: bed
# Predicted label for 3efa7ec4_nohash_2.wav: bed
# Real label for 3efa7ec4_nohash_2.wav: bed
# Predicted label for 3f170018_nohash_0.wav: bed
# Real label for 3f170018_nohash_0.wav: bed
# Predicted label for 3f2b358d_nohash_0.wav: go
# Real label for 3f2b358d_nohash_0.wav: bed
# Predicted label for 3f339c33_nohash_0.wav: bed
# Real label for 3f339c33_nohash_0.wav: bed
# Predicted label for 3fb8c268_nohash_0.wav: bed
# Real label for 3fb8c268_nohash_0.wav: bed
# Predicted label for 3fdafe25_nohash_0.wav: bed
# Real label for 3fdafe25_nohash_0.wav: bed
# Predicted label for 3ff840aa_nohash_0.wav: bed
# Real label for 3ff840aa_nohash_0.wav: bed
# Predicted label for 3ff840aa_nohash_1.wav: bed
# Real label for 3ff840aa_nohash_1.wav: bed
# Predicted label for 40115b19_nohash_0.wav: bed
# Real label for 40115b19_nohash_0.wav: bed
# Predicted label for 402e2977_nohash_0.wav: unknown
# Real label for 402e2977_nohash_0.wav: bed
# Predicted label for 402e2977_nohash_1.wav: unknown
# Real label for 402e2977_nohash_1.wav: bed
# Predicted label for 409c962a_nohash_0.wav: bed
# Real label for 409c962a_nohash_0.wav: bed
# Predicted label for 409c962a_nohash_1.wav: bed
# Real label for 409c962a_nohash_1.wav: bed
# Predicted label for 409c962a_nohash_2.wav: bed
# Real label for 409c962a_nohash_2.wav: bed
# Predicted label for 413997c1_nohash_0.wav: bed
# Real label for 413997c1_nohash_0.wav: bed
# Predicted label for 413bcfe1_nohash_0.wav: bed
# Real label for 413bcfe1_nohash_0.wav: bed
# Predicted label for 41474817_nohash_0.wav: bed
# Real label for 41474817_nohash_0.wav: bed
# Predicted label for 41777abb_nohash_0.wav: bed
# Real label for 41777abb_nohash_0.wav: bed
# Predicted label for 418e7158_nohash_0.wav: bed
# Real label for 418e7158_nohash_0.wav: bed
# Predicted label for 41dce6f5_nohash_0.wav: bed
# Real label for 41dce6f5_nohash_0.wav: bed
# Predicted label for 422d3197_nohash_0.wav: bed
# Real label for 422d3197_nohash_0.wav: bed
# Predicted label for 4290ca61_nohash_0.wav: bed
# Real label for 4290ca61_nohash_0.wav: bed
# Predicted label for 42c6fff1_nohash_0.wav: bed
# Real label for 42c6fff1_nohash_0.wav: bed
# Predicted label for 42c6fff1_nohash_1.wav: bed
# Real label for 42c6fff1_nohash_1.wav: bed
# Predicted label for 42c6fff1_nohash_2.wav: bed
# Real label for 42c6fff1_nohash_2.wav: bed
# Predicted label for 42ccb57a_nohash_0.wav: bed
# Real label for 42ccb57a_nohash_0.wav: bed
# Predicted label for 42e3f068_nohash_0.wav: bed
# Real label for 42e3f068_nohash_0.wav: bed
# Predicted label for 42e3f068_nohash_1.wav: bed
# Real label for 42e3f068_nohash_1.wav: bed
# Predicted label for 435f9f9e_nohash_0.wav: bed
# Real label for 435f9f9e_nohash_0.wav: bed
# Predicted label for 43691f67_nohash_0.wav: bed
# Real label for 43691f67_nohash_0.wav: bed
# Predicted label for 439c84f4_nohash_0.wav: bed
# Real label for 439c84f4_nohash_0.wav: bed
# Predicted label for 43b85b64_nohash_0.wav: bed
# Real label for 43b85b64_nohash_0.wav: bed
# Predicted label for 43b85b64_nohash_1.wav: bed
# Real label for 43b85b64_nohash_1.wav: bed
# Predicted label for 43f57297_nohash_0.wav: bed
# Real label for 43f57297_nohash_0.wav: bed
# Predicted label for 43f57297_nohash_1.wav: bed
# Real label for 43f57297_nohash_1.wav: bed
# Predicted label for 43fc47a7_nohash_0.wav: bed
# Real label for 43fc47a7_nohash_0.wav: bed
# Predicted label for 4407ba92_nohash_0.wav: bed
# Real label for 4407ba92_nohash_0.wav: bed
# Predicted label for 4407ba92_nohash_1.wav: bed
# Real label for 4407ba92_nohash_1.wav: bed
# Predicted label for 44260689_nohash_0.wav: bed
# Real label for 44260689_nohash_0.wav: bed
# Predicted label for 44b5720d_nohash_0.wav: bed
# Real label for 44b5720d_nohash_0.wav: bed
# Predicted label for 44b5720d_nohash_1.wav: bed
# Real label for 44b5720d_nohash_1.wav: bed
# Predicted label for 44b5720d_nohash_2.wav: bed
# Real label for 44b5720d_nohash_2.wav: bed
# Predicted label for 44bc77f7_nohash_0.wav: bed
# Real label for 44bc77f7_nohash_0.wav: bed
# Predicted label for 44c201dd_nohash_0.wav: bed
# Real label for 44c201dd_nohash_0.wav: bed
# Predicted label for 460f2bad_nohash_0.wav: bed
# Real label for 460f2bad_nohash_0.wav: bed
# Predicted label for 46114b4e_nohash_0.wav: bed
# Real label for 46114b4e_nohash_0.wav: bed
# Predicted label for 46114b4e_nohash_1.wav: bed
# Real label for 46114b4e_nohash_1.wav: bed
# Predicted label for 46114b4e_nohash_2.wav: bed
# Real label for 46114b4e_nohash_2.wav: bed
# Predicted label for 4620dc14_nohash_0.wav: bed
# Real label for 4620dc14_nohash_0.wav: bed
# Predicted label for 462e1919_nohash_0.wav: bed
# Real label for 462e1919_nohash_0.wav: bed
# Predicted label for 462e1919_nohash_1.wav: bed
# Real label for 462e1919_nohash_1.wav: bed
# Predicted label for 46a153d8_nohash_0.wav: cat
# Real label for 46a153d8_nohash_0.wav: bed
# Predicted label for 471a0925_nohash_0.wav: three
# Real label for 471a0925_nohash_0.wav: bed
# Predicted label for 47565088_nohash_0.wav: bed
# Real label for 47565088_nohash_0.wav: bed
# Predicted label for 47565088_nohash_1.wav: bed
# Real label for 47565088_nohash_1.wav: bed
# Predicted label for 47565088_nohash_2.wav: bed
# Real label for 47565088_nohash_2.wav: bed
# Predicted label for 479e64cc_nohash_0.wav: bed
# Real label for 479e64cc_nohash_0.wav: bed
# Predicted label for 479e64cc_nohash_1.wav: bed
# Real label for 479e64cc_nohash_1.wav: bed
# Predicted label for 47d01978_nohash_0.wav: bed
# Real label for 47d01978_nohash_0.wav: bed
# Predicted label for 4845bb10_nohash_0.wav: bed
# Real label for 4845bb10_nohash_0.wav: bed
# Predicted label for 48463cbc_nohash_0.wav: bed
# Real label for 48463cbc_nohash_0.wav: bed
# Predicted label for 48463cbc_nohash_1.wav: bed
# Real label for 48463cbc_nohash_1.wav: bed
# Predicted label for 48463cbc_nohash_2.wav: bed
# Real label for 48463cbc_nohash_2.wav: bed
# Predicted label for 48a9f771_nohash_0.wav: bed
# Real label for 48a9f771_nohash_0.wav: bed
# Predicted label for 48a9f771_nohash_1.wav: unknown
# Real label for 48a9f771_nohash_1.wav: bed
# Predicted label for 48bdc11c_nohash_0.wav: bed
# Real label for 48bdc11c_nohash_0.wav: bed
# Predicted label for 48e8b82a_nohash_0.wav: bed
# Real label for 48e8b82a_nohash_0.wav: bed
# Predicted label for 493392c6_nohash_0.wav: bed
# Real label for 493392c6_nohash_0.wav: bed
# Predicted label for 493392c6_nohash_1.wav: bed
# Real label for 493392c6_nohash_1.wav: bed
# Predicted label for 49af4432_nohash_0.wav: bed
# Real label for 49af4432_nohash_0.wav: bed
# Predicted label for 4a1e736b_nohash_0.wav: bed
# Real label for 4a1e736b_nohash_0.wav: bed
# Predicted label for 4a294341_nohash_0.wav: bed
# Real label for 4a294341_nohash_0.wav: bed
# Predicted label for 4a803e67_nohash_0.wav: bed
# Real label for 4a803e67_nohash_0.wav: bed
# Predicted label for 4a803e67_nohash_1.wav: bed
# Real label for 4a803e67_nohash_1.wav: bed
# Predicted label for 4abb2400_nohash_0.wav: bed
# Real label for 4abb2400_nohash_0.wav: bed
# Predicted label for 4abb2400_nohash_1.wav: bed
# Real label for 4abb2400_nohash_1.wav: bed
# Predicted label for 4abefdf5_nohash_0.wav: bed
# Real label for 4abefdf5_nohash_0.wav: bed
# Predicted label for 4b25f620_nohash_0.wav: bed
# Real label for 4b25f620_nohash_0.wav: bed
# Predicted label for 4b25f620_nohash_1.wav: bed
# Real label for 4b25f620_nohash_1.wav: bed
# Predicted label for 4bb1244f_nohash_0.wav: bed
# Real label for 4bb1244f_nohash_0.wav: bed
# Predicted label for 4bb1244f_nohash_1.wav: bed
# Real label for 4bb1244f_nohash_1.wav: bed
# Predicted label for 4beff0c5_nohash_0.wav: bed
# Real label for 4beff0c5_nohash_0.wav: bed
# Predicted label for 4beff0c5_nohash_1.wav: bed
# Real label for 4beff0c5_nohash_1.wav: bed
# Predicted label for 4beff0c5_nohash_2.wav: bed
# Real label for 4beff0c5_nohash_2.wav: bed
# Predicted label for 4c13fe25_nohash_0.wav: bed
# Real label for 4c13fe25_nohash_0.wav: bed
# Predicted label for 4c13fe25_nohash_1.wav: bed
# Real label for 4c13fe25_nohash_1.wav: bed
# Predicted label for 4c13fe25_nohash_2.wav: bed
# Real label for 4c13fe25_nohash_2.wav: bed
# Predicted label for 4c432947_nohash_0.wav: bed
# Real label for 4c432947_nohash_0.wav: bed
# Predicted label for 4c432947_nohash_1.wav: bed
# Real label for 4c432947_nohash_1.wav: bed
# Predicted label for 4c432947_nohash_2.wav: bed
# Real label for 4c432947_nohash_2.wav: bed
# Predicted label for 4c4d2526_nohash_0.wav: bed
# Real label for 4c4d2526_nohash_0.wav: bed
# Predicted label for 4c7c95de_nohash_0.wav: bed
# Real label for 4c7c95de_nohash_0.wav: bed
# Predicted label for 4c7c95de_nohash_1.wav: bed
# Real label for 4c7c95de_nohash_1.wav: bed
# Predicted label for 4c841771_nohash_0.wav: bed
# Real label for 4c841771_nohash_0.wav: bed
# Predicted label for 4ca37738_nohash_0.wav: bed
# Real label for 4ca37738_nohash_0.wav: bed
# Predicted label for 4ca37738_nohash_1.wav: bed
# Real label for 4ca37738_nohash_1.wav: bed
# Predicted label for 4cb874bb_nohash_0.wav: bed
# Real label for 4cb874bb_nohash_0.wav: bed
# Predicted label for 4d9e07cf_nohash_0.wav: bed
# Real label for 4d9e07cf_nohash_0.wav: bed
# Predicted label for 4def68db_nohash_0.wav: bed
# Real label for 4def68db_nohash_0.wav: bed
# Predicted label for 4def68db_nohash_1.wav: bed
# Real label for 4def68db_nohash_1.wav: bed
# Predicted label for 4f086393_nohash_0.wav: bed
# Real label for 4f086393_nohash_0.wav: bed
# Predicted label for 4f086393_nohash_1.wav: bed
# Real label for 4f086393_nohash_1.wav: bed
# Predicted label for 4f256313_nohash_0.wav: bed
# Real label for 4f256313_nohash_0.wav: bed
# Predicted label for 4f2ab70c_nohash_0.wav: bed
# Real label for 4f2ab70c_nohash_0.wav: bed
# Predicted label for 4f8ef132_nohash_0.wav: bed
# Real label for 4f8ef132_nohash_0.wav: bed
# Predicted label for 50033893_nohash_0.wav: unknown
# Real label for 50033893_nohash_0.wav: bed
# Predicted label for 50033893_nohash_1.wav: bed
# Real label for 50033893_nohash_1.wav: bed
# Predicted label for 50033893_nohash_2.wav: bed
# Real label for 50033893_nohash_2.wav: bed
# Predicted label for 50a7d406_nohash_0.wav: bed
# Real label for 50a7d406_nohash_0.wav: bed
# Predicted label for 50a8ef27_nohash_0.wav: bed
# Real label for 50a8ef27_nohash_0.wav: bed
# Predicted label for 50d1c8e3_nohash_0.wav: bed
# Real label for 50d1c8e3_nohash_0.wav: bed
# Predicted label for 50ed8a7b_nohash_0.wav: bed
# Real label for 50ed8a7b_nohash_0.wav: bed
# Predicted label for 50f55535_nohash_0.wav: bed
# Real label for 50f55535_nohash_0.wav: bed
# Predicted label for 51055bda_nohash_0.wav: bed
# Real label for 51055bda_nohash_0.wav: bed
# Predicted label for 512dc91a_nohash_0.wav: bed
# Real label for 512dc91a_nohash_0.wav: bed
# Predicted label for 512dc91a_nohash_1.wav: bed
# Real label for 512dc91a_nohash_1.wav: bed
# Predicted label for 5165cf0a_nohash_0.wav: bed
# Real label for 5165cf0a_nohash_0.wav: bed
# Predicted label for 518588b6_nohash_0.wav: bed
# Real label for 518588b6_nohash_0.wav: bed
# Predicted label for 518588b6_nohash_1.wav: bed
# Real label for 518588b6_nohash_1.wav: bed
# Predicted label for 518588b6_nohash_2.wav: bed
# Real label for 518588b6_nohash_2.wav: bed
# Predicted label for 51995cea_nohash_0.wav: bed
# Real label for 51995cea_nohash_0.wav: bed
# Predicted label for 520b2c17_nohash_0.wav: bed
# Real label for 520b2c17_nohash_0.wav: bed
# Predicted label for 5236848b_nohash_0.wav: bed
# Real label for 5236848b_nohash_0.wav: bed
# Predicted label for 529eda42_nohash_0.wav: bed
# Real label for 529eda42_nohash_0.wav: bed
# Predicted label for 52bfbce8_nohash_0.wav: bed
# Real label for 52bfbce8_nohash_0.wav: bed
# Predicted label for 52bfbce8_nohash_1.wav: bed
# Real label for 52bfbce8_nohash_1.wav: bed
# Predicted label for 52e228e9_nohash_0.wav: bed
# Real label for 52e228e9_nohash_0.wav: bed
# Predicted label for 531a5b8a_nohash_0.wav: bed
# Real label for 531a5b8a_nohash_0.wav: bed
# Predicted label for 531a5b8a_nohash_1.wav: bed
# Real label for 531a5b8a_nohash_1.wav: bed
# Predicted label for 533c6564_nohash_0.wav: bed
# Real label for 533c6564_nohash_0.wav: bed
# Predicted label for 53458368_nohash_0.wav: bed
# Real label for 53458368_nohash_0.wav: bed
# Predicted label for 538e1856_nohash_0.wav: bed
# Real label for 538e1856_nohash_0.wav: bed
# Predicted label for 53fd1780_nohash_0.wav: bed
# Real label for 53fd1780_nohash_0.wav: bed
# Predicted label for 541120c7_nohash_0.wav: bed
# Real label for 541120c7_nohash_0.wav: bed
# Predicted label for 541e4079_nohash_0.wav: bed
# Real label for 541e4079_nohash_0.wav: bed
# Predicted label for 54412eae_nohash_0.wav: bed
# Real label for 54412eae_nohash_0.wav: bed
# Predicted label for 54d9ccb5_nohash_0.wav: bed
# Real label for 54d9ccb5_nohash_0.wav: bed
# Predicted label for 551e42e8_nohash_0.wav: bed
# Real label for 551e42e8_nohash_0.wav: bed
# Predicted label for 553f1a79_nohash_0.wav: bed
# Real label for 553f1a79_nohash_0.wav: bed
# Predicted label for 55d3725a_nohash_0.wav: bed
# Real label for 55d3725a_nohash_0.wav: bed
# Predicted label for 55d3725a_nohash_1.wav: bed
# Real label for 55d3725a_nohash_1.wav: bed
# Predicted label for 563aa4e6_nohash_0.wav: cat
# Real label for 563aa4e6_nohash_0.wav: bed
# Predicted label for 5677ec77_nohash_0.wav: bed
# Real label for 5677ec77_nohash_0.wav: bed
# Predicted label for 5677ec77_nohash_1.wav: bed
# Real label for 5677ec77_nohash_1.wav: bed
# Predicted label for 569455ff_nohash_0.wav: bed
# Real label for 569455ff_nohash_0.wav: bed
# Predicted label for 56eab10e_nohash_0.wav: bed
# Real label for 56eab10e_nohash_0.wav: bed
# Predicted label for 56eab10e_nohash_1.wav: bed
# Real label for 56eab10e_nohash_1.wav: bed
# Predicted label for 56eab10e_nohash_2.wav: bed
# Real label for 56eab10e_nohash_2.wav: bed
# Predicted label for 56eab10e_nohash_3.wav: bed
# Real label for 56eab10e_nohash_3.wav: bed
# Predicted label for 56eb74ae_nohash_0.wav: bed
# Real label for 56eb74ae_nohash_0.wav: bed
# Predicted label for 5705a0f9_nohash_0.wav: bed
# Real label for 5705a0f9_nohash_0.wav: bed
# Predicted label for 5705a0f9_nohash_1.wav: bed
# Real label for 5705a0f9_nohash_1.wav: bed
# Predicted label for 57376a4c_nohash_0.wav: bed
# Real label for 57376a4c_nohash_0.wav: bed
# Predicted label for 573cdb8a_nohash_0.wav: cat
# Real label for 573cdb8a_nohash_0.wav: bed
# Predicted label for 5744b6a7_nohash_0.wav: bed
# Real label for 5744b6a7_nohash_0.wav: bed
# Predicted label for 57b38f48_nohash_0.wav: bed
# Real label for 57b38f48_nohash_0.wav: bed
# Predicted label for 57b38f48_nohash_1.wav: bed
# Real label for 57b38f48_nohash_1.wav: bed
# Predicted label for 57b68383_nohash_0.wav: bed
# Real label for 57b68383_nohash_0.wav: bed
# Predicted label for 57cb3575_nohash_0.wav: bed
# Real label for 57cb3575_nohash_0.wav: bed
# Predicted label for 57cb3575_nohash_1.wav: bed
# Real label for 57cb3575_nohash_1.wav: bed
# Predicted label for 5828dfa2_nohash_0.wav: bed
# ...
# Real label for e652590d_nohash_1.wav: bird
# Predicted label for e6e29c47_nohash_0.wav: bird
# Real label for e6e29c47_nohash_0.wav: bird
# Predicted label for e7117d00_nohash_0.wav: bird
# Real label for e7117d00_nohash_0.wav: bird
# Predicted label for e71b4ce6_nohash_0.wav: bird
# Real label for e71b4ce6_nohash_0.wav: bird
# Predicted label for e7334395_nohash_0.wav: bird
# Real label for e7334395_nohash_0.wav: bird
# Predicted label for e7334395_nohash_1.wav: bird
# Real label for e7334395_nohash_1.wav: bird
# Predicted label for e77d88fc_nohash_0.wav: bird
# Real label for e77d88fc_nohash_0.wav: bird
# Predicted label for e77d88fc_nohash_1.wav: bird
# Real label for e77d88fc_nohash_1.wav: bird
# Predicted label for e7ea8b76_nohash_0.wav: bird
# Real label for e7ea8b76_nohash_0.wav: bird
# Predicted label for e7ebf59c_nohash_0.wav: unknown
# Real label for e7ebf59c_nohash_0.wav: bird
# Predicted label for e805a617_nohash_0.wav: bird
# Real label for e805a617_nohash_0.wav: bird
# Predicted label for e805a617_nohash_1.wav: bird
# Real label for e805a617_nohash_1.wav: bird
# Predicted label for e805a617_nohash_2.wav: bird
# Real label for e805a617_nohash_2.wav: bird
# Predicted label for e82914c0_nohash_0.wav: bird
# Real label for e82914c0_nohash_0.wav: bird
# Predicted label for e8c3c5ca_nohash_0.wav: bird
# Real label for e8c3c5ca_nohash_0.wav: bird
# Predicted label for e900b652_nohash_0.wav: bird
# Real label for e900b652_nohash_0.wav: bird
# Predicted label for e91d173e_nohash_0.wav: bird
# Real label for e91d173e_nohash_0.wav: bird
# Predicted label for e91d173e_nohash_1.wav: bird
# Real label for e91d173e_nohash_1.wav: bird
# Predicted label for e95c70e2_nohash_0.wav: bird
# Real label for e95c70e2_nohash_0.wav: bird
# Predicted label for e96a5020_nohash_0.wav: go
# Real label for e96a5020_nohash_0.wav: bird
# Predicted label for e98cb283_nohash_0.wav: bird
# Real label for e98cb283_nohash_0.wav: bird
# Predicted label for e98cb283_nohash_1.wav: bird
# Real label for e98cb283_nohash_1.wav: bird
# Predicted label for e9901cf0_nohash_0.wav: bed
# Real label for e9901cf0_nohash_0.wav: bird
# Predicted label for e99d36c8_nohash_0.wav: bird
# Real label for e99d36c8_nohash_0.wav: bird
# Predicted label for e9b61425_nohash_0.wav: bird
# Real label for e9b61425_nohash_0.wav: bird
# Predicted label for e9b61425_nohash_1.wav: bird
# Real label for e9b61425_nohash_1.wav: bird
# Predicted label for ea356919_nohash_0.wav: bird
# Real label for ea356919_nohash_0.wav: bird
# Predicted label for ea7ca285_nohash_0.wav: bird
# Real label for ea7ca285_nohash_0.wav: bird
# Predicted label for ea9f8e11_nohash_0.wav: bird
# Real label for ea9f8e11_nohash_0.wav: bird
# Predicted label for ea9f8e11_nohash_1.wav: bird
# Real label for ea9f8e11_nohash_1.wav: bird
# Predicted label for ea9f8e11_nohash_2.wav: bed
# Real label for ea9f8e11_nohash_2.wav: bird
# Predicted label for ead2934a_nohash_0.wav: unknown
# Real label for ead2934a_nohash_0.wav: bird
# Predicted label for eb0676ec_nohash_0.wav: go
# Real label for eb0676ec_nohash_0.wav: bird
# Predicted label for eb3d8eb1_nohash_0.wav: bird
# Real label for eb3d8eb1_nohash_0.wav: bird
# Predicted label for eb3f7d82_nohash_0.wav: bed
# Real label for eb3f7d82_nohash_0.wav: bird
# Predicted label for eb67fcbc_nohash_0.wav: bird
# Real label for eb67fcbc_nohash_0.wav: bird
# Predicted label for eb76bc68_nohash_0.wav: bird
# Real label for eb76bc68_nohash_0.wav: bird
# Predicted label for ec201020_nohash_0.wav: bird
# Real label for ec201020_nohash_0.wav: bird
# Predicted label for ec545975_nohash_0.wav: zero
# Real label for ec545975_nohash_0.wav: bird
# Predicted label for ec545975_nohash_1.wav: bird
# Real label for ec545975_nohash_1.wav: bird
# Predicted label for ec545975_nohash_2.wav: bird
# Real label for ec545975_nohash_2.wav: bird
# Predicted label for ec545975_nohash_3.wav: bird
# Real label for ec545975_nohash_3.wav: bird
# Predicted label for ec5ab5d5_nohash_0.wav: bed
# Real label for ec5ab5d5_nohash_0.wav: bird
# Predicted label for ec7d1151_nohash_0.wav: bird
# Real label for ec7d1151_nohash_0.wav: bird
# Predicted label for ecbd8d66_nohash_0.wav: bird
# Real label for ecbd8d66_nohash_0.wav: bird
# Predicted label for ece1a95a_nohash_0.wav: bird
# Real label for ece1a95a_nohash_0.wav: bird
# Predicted label for ecef25ba_nohash_0.wav: bed
# Real label for ecef25ba_nohash_0.wav: bird
# Predicted label for ecef25ba_nohash_1.wav: cat
# Real label for ecef25ba_nohash_1.wav: bird
# Predicted label for ed0720f1_nohash_0.wav: bed
# Real label for ed0720f1_nohash_0.wav: bird
# Predicted label for ed3c2d05_nohash_0.wav: on
# Real label for ed3c2d05_nohash_0.wav: bird
# Predicted label for edd8bfe3_nohash_0.wav: bird
# Real label for edd8bfe3_nohash_0.wav: bird
# Predicted label for edd8bfe3_nohash_1.wav: bird
# Real label for edd8bfe3_nohash_1.wav: bird
# Predicted label for ee07dcb9_nohash_0.wav: bird
# Real label for ee07dcb9_nohash_0.wav: bird
# Predicted label for ee07dcb9_nohash_1.wav: bird
# Real label for ee07dcb9_nohash_1.wav: bird
# Predicted label for ee483d85_nohash_0.wav: cat
# Real label for ee483d85_nohash_0.wav: bird
# Predicted label for ee4a907f_nohash_0.wav: bird
# Real label for ee4a907f_nohash_0.wav: bird
# Predicted label for ee4a907f_nohash_1.wav: unknown
# Real label for ee4a907f_nohash_1.wav: bird
# Predicted label for eee9b9e2_nohash_0.wav: bird
# Real label for eee9b9e2_nohash_0.wav: bird
# Predicted label for eefd26f3_nohash_0.wav: bird
# Real label for eefd26f3_nohash_0.wav: bird
# Predicted label for eefd26f3_nohash_1.wav: bird
# Real label for eefd26f3_nohash_1.wav: bird
# Predicted label for ef2578c0_nohash_0.wav: bird
# Real label for ef2578c0_nohash_0.wav: bird
# Predicted label for ef2578c0_nohash_1.wav: unknown
# Real label for ef2578c0_nohash_1.wav: bird
# Predicted label for efa16ffd_nohash_0.wav: bed
# Real label for efa16ffd_nohash_0.wav: bird
# Predicted label for f0ac2522_nohash_0.wav: bird
# Real label for f0ac2522_nohash_0.wav: bird
# Predicted label for f0ae7203_nohash_0.wav: bird
# Real label for f0ae7203_nohash_0.wav: bird
# Predicted label for f0ebef1b_nohash_0.wav: bird
# Real label for f0ebef1b_nohash_0.wav: bird
# Predicted label for f0edc767_nohash_0.wav: bird
# Real label for f0edc767_nohash_0.wav: bird
# Predicted label for f0edc767_nohash_1.wav: bed
# Real label for f0edc767_nohash_1.wav: bird
# Predicted label for f0edc767_nohash_2.wav: bird
# Real label for f0edc767_nohash_2.wav: bird
# Predicted label for f104f742_nohash_0.wav: unknown
# Real label for f104f742_nohash_0.wav: bird
# Predicted label for f15a354c_nohash_0.wav: bird
# Real label for f15a354c_nohash_0.wav: bird
# Predicted label for f15a354c_nohash_1.wav: bird
# Real label for f15a354c_nohash_1.wav: bird
# Predicted label for f17be97f_nohash_0.wav: bird
# Real label for f17be97f_nohash_0.wav: bird
# Predicted label for f19c1390_nohash_0.wav: bird
# Real label for f19c1390_nohash_0.wav: bird
# Predicted label for f1b35ace_nohash_0.wav: unknown
# Real label for f1b35ace_nohash_0.wav: bird
# Predicted label for f1b35ace_nohash_1.wav: bird
# Real label for f1b35ace_nohash_1.wav: bird
# Predicted label for f1b35ace_nohash_2.wav: bird
# Real label for f1b35ace_nohash_2.wav: bird
# Predicted label for f1d36c53_nohash_0.wav: bird
# Real label for f1d36c53_nohash_0.wav: bird
# Predicted label for f1d36c53_nohash_1.wav: bird
# Real label for f1d36c53_nohash_1.wav: bird
# Predicted label for f292725f_nohash_0.wav: bird
# Real label for f292725f_nohash_0.wav: bird
# Predicted label for f292725f_nohash_1.wav: bird
# Real label for f292725f_nohash_1.wav: bird
# Predicted label for f297e878_nohash_0.wav: bed
# Real label for f297e878_nohash_0.wav: bird
# Predicted label for f2b8fc18_nohash_0.wav: bird
# Real label for f2b8fc18_nohash_0.wav: bird
# Predicted label for f2b8fc18_nohash_1.wav: bird
# Real label for f2b8fc18_nohash_1.wav: bird
# Predicted label for f2b8fc18_nohash_2.wav: bird
# Real label for f2b8fc18_nohash_2.wav: bird
# Predicted label for f2dd248e_nohash_0.wav: bird
# Real label for f2dd248e_nohash_0.wav: bird
# Predicted label for f33660af_nohash_0.wav: bird
# Real label for f33660af_nohash_0.wav: bird
# Predicted label for f33660af_nohash_1.wav: bird
# Real label for f33660af_nohash_1.wav: bird
# Predicted label for f33660af_nohash_2.wav: bird
# Real label for f33660af_nohash_2.wav: bird
# Predicted label for f34e6f44_nohash_0.wav: unknown
# Real label for f34e6f44_nohash_0.wav: bird
# Predicted label for f35eedd7_nohash_0.wav: bird
# Real label for f35eedd7_nohash_0.wav: bird
# Predicted label for f3957e23_nohash_0.wav: bird
# Real label for f3957e23_nohash_0.wav: bird
# Predicted label for f3cee168_nohash_0.wav: bird
# Real label for f3cee168_nohash_0.wav: bird
# Predicted label for f3cee168_nohash_1.wav: bird
# Real label for f3cee168_nohash_1.wav: bird
# Predicted label for f428ca69_nohash_0.wav: bird
# Real label for f428ca69_nohash_0.wav: bird
# Predicted label for f42e234b_nohash_0.wav: bird
# Real label for f42e234b_nohash_0.wav: bird
# Predicted label for f4386675_nohash_0.wav: bird
# Real label for f4386675_nohash_0.wav: bird
# Predicted label for f4504600_nohash_0.wav: bird
# Real label for f4504600_nohash_0.wav: bird
# Predicted label for f47d644e_nohash_0.wav: wow
# Real label for f47d644e_nohash_0.wav: bird
# Predicted label for f4c77b26_nohash_0.wav: bird
# Real label for f4c77b26_nohash_0.wav: bird
# Predicted label for f4f59743_nohash_0.wav: bird
# Real label for f4f59743_nohash_0.wav: bird
# Predicted label for f5496439_nohash_0.wav: bird
# Real label for f5496439_nohash_0.wav: bird
# Predicted label for f5733968_nohash_0.wav: unknown
# Real label for f5733968_nohash_0.wav: bird
# Predicted label for f5c3de1b_nohash_0.wav: bird
# Real label for f5c3de1b_nohash_0.wav: bird
# Predicted label for f5c3de1b_nohash_1.wav: unknown
# Real label for f5c3de1b_nohash_1.wav: bird
# Predicted label for f5d09ebd_nohash_0.wav: bird
# Real label for f5d09ebd_nohash_0.wav: bird
# Predicted label for f5d09ebd_nohash_1.wav: bird
# Real label for f5d09ebd_nohash_1.wav: bird
# Predicted label for f5e5e8b0_nohash_0.wav: bird
# Real label for f5e5e8b0_nohash_0.wav: bird
# Predicted label for f618568f_nohash_0.wav: bird
# Real label for f618568f_nohash_0.wav: bird
# Predicted label for f618568f_nohash_1.wav: bird
# Real label for f618568f_nohash_1.wav: bird
# Predicted label for f638a812_nohash_0.wav: bird
# Real label for f638a812_nohash_0.wav: bird
# Predicted label for f63a6479_nohash_0.wav: bird
# Real label for f63a6479_nohash_0.wav: bird
# Predicted label for f6581345_nohash_0.wav: bird
# Real label for f6581345_nohash_0.wav: bird
# Predicted label for f6581345_nohash_1.wav: bird
# Real label for f6581345_nohash_1.wav: bird
# Predicted label for f6581345_nohash_2.wav: bird
# Real label for f6581345_nohash_2.wav: bird
# Predicted label for f6617a86_nohash_0.wav: bird
# Real label for f6617a86_nohash_0.wav: bird
# Predicted label for f6617a86_nohash_1.wav: bird
# Real label for f6617a86_nohash_1.wav: bird
# Predicted label for f6af2457_nohash_0.wav: bird
# Real label for f6af2457_nohash_0.wav: bird
# Predicted label for f7879738_nohash_0.wav: bird
# Real label for f7879738_nohash_0.wav: bird
# Predicted label for f804cbb3_nohash_0.wav: bird
# Real label for f804cbb3_nohash_0.wav: bird
# Predicted label for f810e799_nohash_0.wav: cat
# Real label for f810e799_nohash_0.wav: bird
# Predicted label for f816db77_nohash_0.wav: bird
# Real label for f816db77_nohash_0.wav: bird
# Predicted label for f839238a_nohash_0.wav: bird
# Real label for f839238a_nohash_0.wav: bird
# Predicted label for f839238a_nohash_1.wav: bird
# Real label for f839238a_nohash_1.wav: bird
# Predicted label for f852895b_nohash_0.wav: bird
# Real label for f852895b_nohash_0.wav: bird
# Predicted label for f875f965_nohash_0.wav: bed
# Real label for f875f965_nohash_0.wav: bird
# Predicted label for f875f965_nohash_1.wav: bird
# Real label for f875f965_nohash_1.wav: bird
# Predicted label for f88f97a7_nohash_0.wav: bed
# Real label for f88f97a7_nohash_0.wav: bird
# Predicted label for f8f60f59_nohash_0.wav: bird
# Real label for f8f60f59_nohash_0.wav: bird
# Predicted label for f9273a21_nohash_0.wav: bed
# Real label for f9273a21_nohash_0.wav: bird
# Predicted label for f9273a21_nohash_1.wav: bird
# Real label for f9273a21_nohash_1.wav: bird
# Predicted label for f92e49f3_nohash_0.wav: bird
# Real label for f92e49f3_nohash_0.wav: bird
# Predicted label for f9318c93_nohash_0.wav: bird
# Real label for f9318c93_nohash_0.wav: bird
# Predicted label for f953e1af_nohash_0.wav: bed
# Real label for f953e1af_nohash_0.wav: bird
# Predicted label for f97e1fcd_nohash_0.wav: bird
# Real label for f97e1fcd_nohash_0.wav: bird
# Predicted label for f9af0887_nohash_0.wav: bird
# Real label for f9af0887_nohash_0.wav: bird
# Predicted label for f9bdf10e_nohash_0.wav: unknown
# Real label for f9bdf10e_nohash_0.wav: bird
# Predicted label for f9ebdba0_nohash_0.wav: wow
# Real label for f9ebdba0_nohash_0.wav: bird
# Predicted label for f9f9751d_nohash_0.wav: bird
# Real label for f9f9751d_nohash_0.wav: bird
# Predicted label for f9f9751d_nohash_1.wav: bird
# Real label for f9f9751d_nohash_1.wav: bird
# Predicted label for fa446c16_nohash_0.wav: bird
# Real label for fa446c16_nohash_0.wav: bird
# Predicted label for fa446c16_nohash_1.wav: bird
# Real label for fa446c16_nohash_1.wav: bird
# Predicted label for fa7895de_nohash_0.wav: bird
# Real label for fa7895de_nohash_0.wav: bird
# Predicted label for fa7895de_nohash_1.wav: bird
# Real label for fa7895de_nohash_1.wav: bird
# Predicted label for fac74f6a_nohash_0.wav: bird
# Real label for fac74f6a_nohash_0.wav: bird
# Predicted label for fac7deca_nohash_0.wav: bed
# Real label for fac7deca_nohash_0.wav: bird
# Predicted label for fad7a69a_nohash_0.wav: bird
# Real label for fad7a69a_nohash_0.wav: bird
# Predicted label for fad7a69a_nohash_1.wav: bird
# Real label for fad7a69a_nohash_1.wav: bird
# Predicted label for fafe8101_nohash_0.wav: bird
# Real label for fafe8101_nohash_0.wav: bird
# Predicted label for fb2f3242_nohash_0.wav: bird
# Real label for fb2f3242_nohash_0.wav: bird
# Predicted label for fb7c9b3b_nohash_0.wav: bird
# Real label for fb7c9b3b_nohash_0.wav: bird
# Predicted label for fb9d6d23_nohash_0.wav: bird
# Real label for fb9d6d23_nohash_0.wav: bird
# Predicted label for fbdc07bb_nohash_0.wav: bird
# Real label for fbdc07bb_nohash_0.wav: bird
# Predicted label for fbe51750_nohash_0.wav: bird
# Real label for fbe51750_nohash_0.wav: bird
# Predicted label for fbf3dd31_nohash_0.wav: bird
# Real label for fbf3dd31_nohash_0.wav: bird
# Predicted label for fbf3dd31_nohash_1.wav: bird
# Real label for fbf3dd31_nohash_1.wav: bird
# Predicted label for fc94edb0_nohash_0.wav: bird
# Real label for fc94edb0_nohash_0.wav: bird
# Predicted label for fc94edb0_nohash_1.wav: bird
# Real label for fc94edb0_nohash_1.wav: bird
# Predicted label for fce65496_nohash_0.wav: bird
# Real label for fce65496_nohash_0.wav: bird
# Predicted label for fd395b74_nohash_0.wav: go
# Real label for fd395b74_nohash_0.wav: bird
# Predicted label for fda46b78_nohash_0.wav: bird
# Real label for fda46b78_nohash_0.wav: bird
# Predicted label for fda46b78_nohash_1.wav: bird
# Real label for fda46b78_nohash_1.wav: bird
# Predicted label for fda46b78_nohash_2.wav: bird
# Real label for fda46b78_nohash_2.wav: bird
# Predicted label for fde2dee7_nohash_0.wav: bird
# Real label for fde2dee7_nohash_0.wav: bird
# Predicted label for fde2dee7_nohash_1.wav: bird
# Real label for fde2dee7_nohash_1.wav: bird
# Predicted label for fe291fa9_nohash_0.wav: bird
# Real label for fe291fa9_nohash_0.wav: bird
# Predicted label for fe291fa9_nohash_1.wav: bird
# Real label for fe291fa9_nohash_1.wav: bird
# Predicted label for fe5c4a7a_nohash_0.wav: bird
# Real label for fe5c4a7a_nohash_0.wav: bird
# Predicted label for fe5c4a7a_nohash_1.wav: bird
# Real label for fe5c4a7a_nohash_1.wav: bird
# Predicted label for ff63ab0b_nohash_0.wav: bed
# Real label for ff63ab0b_nohash_0.wav: bird
# Predicted label for ff63ab0b_nohash_1.wav: bed
# Real label for ff63ab0b_nohash_1.wav: bird
# Predicted label for ff63ab0b_nohash_2.wav: bed
# Real label for ff63ab0b_nohash_2.wav: bird
# Predicted label for ffa76c4a_nohash_0.wav: bird
# Real label for ffa76c4a_nohash_0.wav: bird
# Predicted label for ffb86d3c_nohash_0.wav: bird
# Real label for ffb86d3c_nohash_0.wav: bird
# Predicted label for ffb86d3c_nohash_1.wav: bird
# Real label for ffb86d3c_nohash_1.wav: bird
# Predicted label for ffd2ba2f_nohash_0.wav: bird
# Real label for ffd2ba2f_nohash_0.wav: bird
# Accuracy: 0.8275261324041812

# %%
import os

# Ścieżka do folderu audio
audio_dir = 'data/train/audio'

# Ścieżki do plików z listami testowymi i walidacyjnymi
testing_list_path = 'data/train/testing_list.txt'
validation_list_path = 'data/train/validation_list.txt'

# Wczytaj zawartość plików do list
with open(testing_list_path, 'r') as file:
    testing_list = file.read().splitlines()

with open(validation_list_path, 'r') as file:
    validation_list = file.read().splitlines()

# Pobierz wszystkie podkatalogi w folderze audio
all_subdirs = os.listdir(audio_dir)

# Filtruj tylko katalogi (pomijając pliki)
available_labels = [dir_name for dir_name in all_subdirs if os.path.isdir(os.path.join(audio_dir, dir_name))]

# Inicjalizuj listę plików treningowych
training_files = []

# Przejdź przez wszystkie dostępne etykiety
for label in available_labels:
    label_dir = os.path.join(audio_dir, label)

    # Upewnij się, że katalog istnieje
    if os.path.isdir(label_dir):
        # Pobierz wszystkie pliki w katalogu
        all_files = os.listdir(label_dir)

        # Filtruj tylko pliki audio
        audio_files = [file for file in all_files if file.endswith('.wav')]

        # Przejdź przez wszystkie pliki audio
        for audio_file in audio_files:
            # Utwórz ścieżkę do pliku audio
            audio_path = os.path.join(label, audio_file)

            # Jeśli plik audio nie jest na liście testowej ani walidacyjnej, dodaj go do listy treningowej
            if audio_path not in testing_list and audio_path not in validation_list:
                training_files.append(audio_path)

print(f"Number of training files: {len(training_files)}")
# Out:
# Number of training files: 64727

# %%
# Ścieżka do nowego pliku
training_list_path = 'data/train/training_list.txt'

# Otwórz plik w trybie zapisu
with open(training_list_path, 'w') as file:
    # Przejdź przez wszystkie pliki treningowe
    for training_file in training_files:
        # Dodaj ścieżkę do pliku do pliku treningowego
        file.write(training_file + '\n')

print(f"Training file paths have been written to {training_list_path}")
# Out:
# Training file paths have been written to data/train/training_list.txt

# %%
from datasets import Dataset
from transformers import Wav2Vec2Processor
import soundfile as sf

# Ścieżka do folderu audio
audio_dir = 'data/train/audio'

# Inicjalizuj procesor
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")

# Inicjalizuj listy do przechowywania danych
input_values = []
labels = []

# Przejdź przez wszystkie pliki treningowe
for audio_file in training_files:
    # Utwórz pełną ścieżkę do pliku audio
    audio_path = os.path.join(audio_dir, audio_file)

    # Wczytaj plik audio
    audio, _ = sf.read(audio_path)

    # Przetwórz audio za pomocą procesora
    input_value = processor(audio, return_tensors="pt", padding=True, sampling_rate=16000).input_values[0]

    # Dodaj wartości wejściowe do listy
    input_values.append(input_value)

    # Wyodrębnij etykietę z nazwy pliku
    label = os.path.basename(os.path.dirname(audio_file))

    # Przetwórz etykietę za pomocą procesora
    label_id = processor.tokenizer(label, return_tensors="pt").input_ids[0]

    # Dodaj identyfikator etykiety do listy
    labels.append(label_id)

# Utwórz zestaw danych
dataset = Dataset.from_dict({"input_values": input_values, "labels": labels})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 39
#      36     labels.append(label_id)
#      38 # Utwórz zestaw danych
# ---> 39 dataset = Dataset.from_dict({"input_values": input_values, "labels": labels})
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\arrow_dataset.py:925, in Dataset.from_dict(cls, mapping, features, info, split)
#     916 if info.features is None:
#     917     info.features = Features(
#     918         {
#     919             col: generate_from_arrow_type(data.type)
#    (...)
#     923         }
#     924     )
# --> 925 return cls(pa_table, info=info, split=split)
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\arrow_dataset.py:708, in Dataset.__init__(self, arrow_table, info, split, indices_table, fingerprint)
#     705 # Infer fingerprint if None
#     707 if self._fingerprint is None:
# --> 708     self._fingerprint = generate_fingerprint(self)
#     710 # Sanity checks
#     712 if self._info.features is None:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\fingerprint.py:256, in generate_fingerprint(dataset)
#     254         continue
#     255     hasher.update(key)
# --> 256     hasher.update(state[key])
#     257 # hash data files last modification timestamps as well
#     258 for cache_file in dataset.cache_files:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\fingerprint.py:232, in Hasher.update(self, value)
#     230 def update(self, value: Any) -> None:
#     231     header_for_update = f"=={type(value)}=="
# --> 232     value_for_update = self.hash(value)
#     233     self.m.update(header_for_update.encode("utf8"))
#     234     self.m.update(value_for_update.encode("utf-8"))
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\fingerprint.py:228, in Hasher.hash(cls, value)
#     226 @classmethod
#     227 def hash(cls, value: Any) -> str:
# --> 228     return cls.hash_bytes(dumps(value))
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:109, in dumps(obj)
#     107 """Pickle an object to a string."""
#     108 file = BytesIO()
# --> 109 dump(obj, file)
#     110 return file.getvalue()
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:103, in dump(obj, file)
#     101 def dump(obj, file):
#     102     """Pickle an object to a file."""
# --> 103     Pickler(file, recurse=True).dump(obj)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:420, in Pickler.dump(self, obj)
#     418 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     419     logger.trace_setup(self)
# --> 420     StockPickler.dump(self, obj)
#
# File C:\Program Files\Python311\Lib\pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File C:\Program Files\Python311\Lib\pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File C:\Program Files\Python311\Lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:83, in Pickler._batch_setitems(self, items)
#      80     from datasets.fingerprint import Hasher
#      82     items = sorted(items, key=lambda x: Hasher.hash(x[0]))
# ---> 83 dill.Pickler._batch_setitems(self, items)
#
# File C:\Program Files\Python311\Lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File C:\Program Files\Python311\Lib\pickle.py:959, in _Pickler._batch_appends(self, items)
#     957     write(APPENDS)
#     958 elif n:
# --> 959     save(tmp[0])
#     960     write(APPEND)
#     961 # else tmp is empty, and we're done
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File C:\Program Files\Python311\Lib\pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File C:\Program Files\Python311\Lib\pickle.py:956, in _Pickler._batch_appends(self, items)
#     954     write(MARK)
#     955     for x in tmp:
# --> 956         save(x)
#     957     write(APPENDS)
#     958 elif n:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File C:\Program Files\Python311\Lib\pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:902, in _Pickler.save_tuple(self, obj)
#     900 write(MARK)
#     901 for element in obj:
# --> 902     save(element)
#     904 if id(obj) in memo:
#     905     # Subtle.  d was not in memo when we entered save_tuple(), so
#     906     # the process of saving the tuple's elements must have saved
#    (...)
#     910     # could have been done in the "for element" loop instead, but
#     911     # recursive tuples are a rare thing.
#     912     get = self.get(memo[id(obj)][0])
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File C:\Program Files\Python311\Lib\pickle.py:959, in _Pickler._batch_appends(self, items)
#     957     write(APPENDS)
#     958 elif n:
# --> 959     save(tmp[0])
#     960     write(APPEND)
#     961 # else tmp is empty, and we're done
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:902, in _Pickler.save_tuple(self, obj)
#     900 write(MARK)
#     901 for element in obj:
# --> 902     save(element)
#     904 if id(obj) in memo:
#     905     # Subtle.  d was not in memo when we entered save_tuple(), so
#     906     # the process of saving the tuple's elements must have saved
#    (...)
#     910     # could have been done in the "for element" loop instead, but
#     911     # recursive tuples are a rare thing.
#     912     get = self.get(memo[id(obj)][0])
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File C:\Program Files\Python311\Lib\pickle.py:956, in _Pickler._batch_appends(self, items)
#     954     write(MARK)
#     955     for x in tmp:
# --> 956         save(x)
#     957     write(APPENDS)
#     958 elif n:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File C:\Program Files\Python311\Lib\pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:814, in _Pickler.save_bytearray(self, obj)
#     812         self.save_reduce(bytearray, (), obj=obj)
#     813     else:
# --> 814         self.save_reduce(bytearray, (bytes(obj),), obj=obj)
#     815     return
#     816 n = len(obj)
#
# File C:\Program Files\Python311\Lib\pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File ~\Documents\DS\venv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~\Documents\DS\venv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File C:\Program Files\Python311\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File C:\Program Files\Python311\Lib\pickle.py:803, in _Pickler.save_bytes(self, obj)
#     801     self._write_large_bytes(BINBYTES8 + pack("<Q", n), obj)
#     802 elif n >= self.framer._FRAME_SIZE_TARGET:
# --> 803     self._write_large_bytes(BINBYTES + pack("<I", n), obj)
#     804 else:
#     805     self.write(BINBYTES + pack("<I", n) + obj)
#
# File C:\Program Files\Python311\Lib\pickle.py:260, in _Framer.write_large_bytes(self, header, payload)
#     253 # Perform direct write of the header and payload of the large binary
#     254 # object. Be careful not to concatenate the header and the payload
#     255 # prior to calling 'write' as we do not want to allocate a large
#     256 # temporary bytes object.
#     257 # We intentionally do not insert a protocol 4 frame opcode to make
#     258 # it possible to optimize file.read calls in the loader.
#     259 write(header)
# --> 260 write(payload)
#
# MemoryError:

# %%
import numpy as np
from transformers import Wav2Vec2ForCTC, TrainingArguments, Trainer
from datasets import load_metric

# Inicjalizuj model
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# Zdefiniuj argumenty treningowe
training_args = TrainingArguments(
    output_dir='./results',          # ścieżka wyjściowa dla zapisywania modelu
    num_train_epochs=3,              # liczba epok treningowych
    per_device_train_batch_size=16,  # rozmiar batcha dla treningu
    per_device_eval_batch_size=64,   # rozmiar batcha dla ewaluacji
    warmup_steps=500,                # liczba kroków rozgrzewki
    weight_decay=0.01,               # współczynnik zaniku wagi
    logging_dir='./logs',            # ścieżka do zapisywania logów
)

# Zdefiniuj funkcję do obliczania metryki podczas treningu
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer_metric = load_metric("wer")
    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# Zainicjuj trenera
trainer = Trainer(
    model=model,                         # model do trenowania
    args=training_args,                  # argumenty treningowe
    train_dataset=dataset,               # dane treningowe
    compute_metrics=compute_metrics,     # funkcja do obliczania metryk
)

# Rozpocznij trening
trainer.train()
# Step 1: Evaluate the model
eval_result = trainer.evaluate()

# Print the evaluation result
print(f"Evaluation Result: {eval_result}")

# Step 2: Save the model
model_path = "./wav2vec2_trained_model"
model.save_pretrained(model_path)
processor.save_pretrained(model_path)

# Step 3: Use the model for inference
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Load the saved model and processor
model = Wav2Vec2ForCTC.from_pretrained(model_path)
processor = Wav2Vec2Processor.from_pretrained(model_path)

# Assume we have a new audio file for inference
new_audio_file = "path_to_your_audio_file.wav"

# Load and preprocess the audio file
audio, rate = librosa.load(new_audio_file, sr=16000)
inputs = processor(audio, return_tensors="pt", padding=True, sampling_rate=16000)

# Make the prediction
logits = model(**inputs).logits

# Compute the predicted IDs
predicted_ids = torch.argmax(logits, dim=-1)

# Decode the IDs to get the transcription
transcription = processor.decode(predicted_ids[0])

print(f"Transcription for {new_audio_file}: {transcription}")
